# %% [markdown]
# ## Webscraping com `requests` e `BeautifulSoup`
#
# A primeira biblioteca que precisamos é Requests. Ela gerencia a requisição HTTP. Significa que ela acessa e "copia" o código-fonte para nosso script.

# %%
import requests

# %% [markdown]
# Com a biblioteca carregada, vamos gerar a URL do site que desejamos. Neste exemplo, vamos raspar as cota de despesa parlamentar (os gastos no Cotão) do senador Flávio Bolsonaro.

# %%
# A URL é https://www6g.senado.leg.br/transparencia/sen/5894/?ano=2021, mas
# eu costumo separá-la em pedaços para faciliar eventuais for loop
endereco = "https://www6g.senado.leg.br/transparencia/sen/"
senador = "5894"
query_ano = "/?ano="
ano = "2021"
url = endereco + senador + query_ano + ano

print(url)
# Out:
# https://www6g.senado.leg.br/transparencia/sen/5894/?ano=2021

# %% [markdown]
# Agora que temos a URL gerada, vamos fazer com que Requests busque seu conteúdo. Vamos armazenar na variável `site`.

# %%
site = requests.get(url)
# Documentação: https://requests.readthedocs.io/en/master/api/#requests.get

# %% [markdown]
# Com a captura do código-fonte feita, podemos ver o resultado usando `status_code` (se conseguimos conexão com o servidor), `headers` (os _headers_ usados na captura), `content` (o conteúdo, o código em bytes), `text` (o conteúdo, o código em unicode, "legível") e outros métodos.
#
# Para saber mais métodos, consulte a [documentação de `requests.Response`](https://requests.readthedocs.io/en/master/api/#requests.Response).

# %%
print(site.status_code)
# Documentação: https://requests.readthedocs.io/en/master/api/#requests.Response.status_code
# Out:
# 200

# %%
print(site.headers)
# Documentação: https://requests.readthedocs.io/en/master/api/#requests.Response.headers
# Out:
# {'Server': 'nginx', 'Date': 'Fri, 27 Aug 2021 18:38:03 GMT', 'Content-Type': 'text/html;charset=UTF-8', 'Content-Length': '7966', 'Connection': 'keep-alive', 'cache-control': 'max-age=900,public', 'content-language': 'pt-BR', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'Age': '3216', 'X-Content-Type-Options': 'nosniff', 'Accept-Ranges': 'bytes'}

# %%
print(site.content)
# Documentação: https://requests.readthedocs.io/en/master/api/#requests.Response.content
# Out:
# b'<!DOCTYPE html>\r\n<html lang="pt-br">\n<head>\n\n<title>Recursos Utilizados por\r\n\tFl\xc3\xa1vio Bolsonaro em\r\n\t2021 - Transpar\xc3\xaancia</title>\n<meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n<meta name="viewport" content="width=device-width, initial-scale=1.0" />\n<meta name="author" content="Senado Federal" />\n\n<link rel="shortcut icon" type="image/x-icon"\n\thref="/transparencia/img/senado/favicon.ico" />\n<link rel="icon" type="image/png"\n\thref="/transparencia/img/senado/icones-tablet/16x16.png" />\n<link rel="apple-touch-icon" type="image/png"\n\thref="/transparencia/img/senado/icones-tablet/114x114.png" />\n<link rel="apple-touch-icon-precomposed" type="image/png"\n\thref="/transparencia/img/senado/icones-tablet/96x96.png" />\n\n<link rel="stylesheet" type="text/css"\n\thref="/transparencia/lib/bootstrap-2.3.2/css/bootstrap.min-282663d1dc8a60dcef58304c09005aa5.css" />\n<link rel="stylesheet" type="text/css"\n\thref="/transparencia/lib/bootstrap-2.3.2/css/bootstrap-responsive-d2c30d07a98d50e945570bf32c56435f.css" />\n<link rel="stylesheet" type="text/css"\n\thref="/transparencia/lib/shell/css/shell-b0aaf685987835264626af667fc80597.css" />\n<link rel="stylesheet" type="text/css"\n\thref="/transparencia/lib/essencial/fat-1282afbf332d5327ecb1ae75e9f114b7.css" />\n<link rel="stylesheet" type="text/css"\n\thref="/transparencia/lib/shell/css/fix-aui-e66c089b905efe6fed9373f7316201e0.css" />\n<link rel="stylesheet" type="text/css"\n\thref="/transparencia/lib/shell/css/painel-ffedaf873ba1ce691e8dbb61f73db776.css" />\n<link rel="stylesheet" type="text/css"\n\thref="/transparencia/lib/shell/css/panel-6ad856905c386078b7078dd6b9382fb7.css" />\n<link rel="stylesheet" type="text/css"\n\thref="/transparencia/lib/shell/css/titulos-d964796b4642a6c84d84357451b6adb1.css" />\n<link rel="stylesheet" type="text/css"\n\thref="/transparencia/css/font-awesome/css/font-awesome-2d53b06f292dcb355b5e1a39ec065054.css" />\n<link rel="stylesheet" type="text/css"\n\thref="/transparencia/lib/bootstrap-datepicker/bootstrap-datepicker-1ff9dc961628101b7a2c5fd77c66ecc3.css" />\n<link rel="stylesheet" type="text/css"\n\thref="/transparencia/lib/jstree/themes/default/style-ec61aa001430a9bf505b7842e4d7a05f.css" />\n<link rel="stylesheet" type="text/css"\n\thref="/transparencia/css/transparencia-31623ffc97b79093f32a490d992180b8.css" />\n<link rel="stylesheet" type="text/css" href="/transparencia/css/senadores-20677867d831fb0e6528b70006b5ca84.css" />\n<link rel="stylesheet" type="text/css"\n\thref="/transparencia/lib/essencial-2020/css/essencial-2a517bbd35b9c42efee45151245150c8.css" />\n<link rel="stylesheet" type="text/css"\n\thref="/transparencia/lib/essencial-2020/css/essencial-fix-bs2-e09537266d2f37581f77ef345b0a0d29.css" />\n\n\t\t\n\t\t\t<script>\n\t\t\t\twindow.ga = window.ga || function() {\n\t\t\t\t\t(ga.q = ga.q || []).push(arguments)\n\t\t\t\t};\n\t\t\t\tga.l = +new Date;\n\t\t\t\tga(\'create\', \'UA-27295293-6\', \'auto\');\n\t\t\t\tga(\'create\', \'UA-101435193-1\', \'auto\', \'global\', {\n\t\t\t\t\t\'alwaysSendReferrer\' : true\n\t\t\t\t});\n\t\t\t\tga(\'send\', \'pageview\');\n\t\t\t\tga(\'global.send\', \'pageview\');\n\t\t\t</script>\n\t\t\t<script async="async"\n\t\t\t\tsrc="https://www.google-analytics.com/analytics.js"></script>\n\t\t\n\t\n<meta name="description"\r\n\tcontent="Resumo de recursos utilizados por [[Fl\xc3\xa1vio Bolsonaro]] em\t[[2021]]" />\n<meta name="keywords"\r\n\tcontent="senado federal, transpar\xc3\xaancia, despesas, senadores" />\n\r\n\t\r\n\t\t\r\n\t\r\n\t\t<meta name="robots" content="index, follow" />\r\n\t\t\r\n\t\t<meta name="sf_ano" content="2021" />\r\n\t\t<meta name="sf_senador"\r\n\t\t\tcontent="Fl\xc3\xa1vio Bolsonaro" />\r\n\t\r\n\r\n\t\r\n\n</head>\n<body class="">\n\t<a class="sr-only" href="#conteudoPrincipal">Ir para conte\xc3\xbado\n\t\tprincipal</a>\n\t<div class="sf-wrapper">\r\n   <div class="js-sidebar-moun ...

# %%
print(site.text)
# Documentação: https://requests.readthedocs.io/en/master/api/#requests.Response.text
# Out:
# <!DOCTYPE html>
# <html lang="pt-br">
# <head>
#
# <title>Recursos Utilizados por
# 	Flávio Bolsonaro em
# 	2021 - Transparência</title>
# <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# <meta name="viewport" content="width=device-width, initial-scale=1.0" />
# <meta name="author" content="Senado Federal" />
#
# <link rel="shortcut icon" type="image/x-icon"
# 	href="/transparencia/img/senado/favicon.ico" />
# <link rel="icon" type="image/png"
# 	href="/transparencia/img/senado/icones-tablet/16x16.png" />
# <link rel="apple-touch-icon" type="image/png"
# 	href="/transparencia/img/senado/icones-tablet/114x114.png" />
# <link rel="apple-touch-icon-precomposed" type="image/png"
# 	href="/transparencia/img/senado/icones-tablet/96x96.png" />
#
# <link rel="stylesheet" type="text/css"
# 	href="/transparencia/lib/bootstrap-2.3.2/css/bootstrap.min-282663d1dc8a60dcef58304c09005aa5.css" />
# <link rel="stylesheet" type="text/css"
# 	href="/transparencia/lib/bootstrap-2.3.2/css/bootstrap-responsive-d2c30d07a98d50e945570bf32c56435f.css" />
# <link rel="stylesheet" type="text/css"
# 	href="/transparencia/lib/shell/css/shell-b0aaf685987835264626af667fc80597.css" />
# <link rel="stylesheet" type="text/css"
# 	href="/transparencia/lib/essencial/fat-1282afbf332d5327ecb1ae75e9f114b7.css" />
# <link rel="stylesheet" type="text/css"
# 	href="/transparencia/lib/shell/css/fix-aui-e66c089b905efe6fed9373f7316201e0.css" />
# <link rel="stylesheet" type="text/css"
# 	href="/transparencia/lib/shell/css/painel-ffedaf873ba1ce691e8dbb61f73db776.css" />
# <link rel="stylesheet" type="text/css"
# 	href="/transparencia/lib/shell/css/panel-6ad856905c386078b7078dd6b9382fb7.css" />
# <link rel="stylesheet" type="text/css"
# 	href="/transparencia/lib/shell/css/titulos-d964796b4642a6c84d84357451b6adb1.css" />
# <link rel="stylesheet" type="text/css"
# 	href="/transparencia/css/font-awesome/css/font-awesome-2d53b06f292dcb355b5e1a39ec065054.css" />
# <link rel="stylesheet" type="text/css"
# 	href="/transparencia/lib/bootstrap-datepicker/bootstrap-datepicker-1ff9dc961628101b7a2c5fd77c66ecc3.css" />
# <link rel="stylesheet" type="text/css"
# 	href="/transparencia/lib/jstree/themes/default/style-ec61aa001430a9bf505b7842e4d7a05f.css" />
# <link rel="stylesheet" type="text/css"
# 	href="/transparencia/css/transparencia-31623ffc97b79093f32a490d992180b8.css" />
# <link rel="stylesheet" type="text/css" href="/transparencia/css/senadores-20677867d831fb0e6528b70006b5ca84.css" />
# <link rel="stylesheet" type="text/css"
# 	href="/transparencia/lib/essencial-2020/css/essencial-2a517bbd35b9c42efee45151245150c8.css" />
# <link rel="stylesheet" type="text/css"
# 	href="/transparencia/lib/essencial-2020/css/essencial-fix-bs2-e09537266d2f37581f77ef345b0a0d29.css" />
#
#
# 			<script>
# 				window.ga = window.ga || function() {
# 					(ga.q = ga.q || []).push(arguments)
# 				};
# 				ga.l = +new Date;
# 				ga('create', 'UA-27295293-6', 'auto');
# 				ga('create', 'UA-101435193-1', 'auto', 'global', {
# 					'alwaysSendReferrer' : true
# 				});
# 				ga('send', 'pageview');
# 				ga('global.send', 'pageview');
# 			</script>
# 			<script async="async"
# 				src="https://www.google-analytics.com/analytics.js"></script>
#
#
# <meta name="description"
# 	content="Resumo de recursos utilizados por [[Flávio Bolsonaro]] em	[[2021]]" />
# <meta name="keywords"
# 	content="senado federal, transparência, despesas, senadores" />
#
#
#
#
# 		<meta name="robots" content="index, follow" />
#
# 		<meta name="sf_ano" content="2021" />
# 		<meta name="sf_senador"
# 			content="Flávio Bolsonaro" />
#
#
#
#
# </head>
# <body class="">
# 	<a class="sr-only" href="#conteudoPrincipal">Ir para conteúdo
# 		principal</a>
# 	<div class="sf-wrapper">
#    <div class="js-sidebar-mountpoint" data-url="https://www12.senado.leg.br/hpsenado/wssidebar.json"></div>
# </div>
# 	<div class="sf-wrapper">
# 	<nav class="Triad navbar_global">
# 		<div>
# 			<button class="btn btn-lg btn-secondary js-sidebar-action"
# 				id="jstoggle" type="button">
# 				<i class="fas fa-bars"></i><span class="u-hideLower title-n">
# 					Menu</span>
# 			</button>
# 		</div>
# 		<div><a class="navbar_global-brand" href="https://www.senado.leg.br" title="Senado Federal"><img
# 			src="https://www.senado.leg.br/noticias/essencial/images/senado.svg"
# 			alt="Senado Federal" /></a>
# 		</div>
# 		<div>
# 			<div class="Rail Rail--fenced u-hideLower">
# 				<a class="js-vlibras" role="button" title="acessibilidade">
# 					<img src="https://www.senado.leg.br/noticias/essencial/images/hands.svg" width="25px" /></a><a
# 					class="link link-deep"
# 					href="https://www12.senado.leg.br/institucional/responsabilidade-social/acessibilidade/pages/acessibilidade-no-portal-do-senado">Acessibilidade</a><a
# 					class="link link-deep"
# 					href="http://www12.senado.gov.br/institucional/falecomosenado">Fale
# 					com o Senado</a>
# 			</div>
# 			<a class="btn btn-lg btn-secondary u-hideUpper"
# 				href="http://www12.senado.gov.br/institucional/falecomosenado"><i
# 				class="fas fa-phone"></i></a>
# 		</div>
# 	</nav>
# </div>
# 	<div class="sf-wrapper">
# 	<div class="menu-local">
# 		<div class="pt-2">
# 			<a class="nav_control-title d-none" href="#" title="Logo Portal"></a>
# 			<div class="nav_control-title">
# 				<h1><a href="https://www12.senado.leg.br/transparencia">Transparência</a>
# 					<span class="next-title">
# 						<a href ="https://www25.senado.leg.br/web/transparencia/sen">Senadores</a>
# 					</span>
# 				</h1>
# 			</div>
# 		</div>
# 		<button class="btn_control-res btn btn-tertiary btn-lg" type="button"
# 			data-toggle="collapse.se" data-target="#menu-local__form"
# 			aria-controls="menu-local__form" aria-expanded="false"
# 			aria-label="Exibe busca">
# 			<i class="fas fa-search"></i>
# 		</button>
# 		<form class="menu-local__form collapse" id="menu-local__form"
# 			method="GET" action="https://www6g.senado.leg.br/busca/">
# 			<input type="hidden" name="portal" value="Transparência" />
# 			<div class="search-wrapper">
# 				<input class="form-control search-out" type="search" name="q"
# 					placeholder="Buscar" />
# 				<button class="search-btn" type="submit">
# 					<i class="fas fa-search"></i>
# 				</button>
# 			</div>
# 		</form>
# 	</div>
# </div>
# 	<div class="sf-wrapper">
# 	<nav class="navbar navbar_control navbar-expand-lg navbar--sf">
# 		<div class="navbar-toggler navbar-toggler--sf" role="button"
# 			data-toggle="collapse.se" data-target="#js-navbar-dropdown"
# 			aria-controls="js-navbar-dropdown" aria-expanded="false"
# 			aria-label="Exibe navegação">
# 			<button class="btn btn-secondary">
# 				<i class="fas fa-bars"></i>
# 			</button>
# 			<div class="ml-2">MENU DESTA SEÇÃO</div>
# 		</div>
# 		<div class="collapse navbar-collapse-se" id="js-navbar-dropdown">
# 			<ul class="navbar-nav navbar-nav--sf">
# 				<li class="nav-item"><a class="link link--nav"
# 					href="https://www25.senado.leg.br/web/transparencia/sen">Senadores</a></li>
# 				<li class="nav-item"><a class="link link--nav"
# 					href="https://www12.senado.leg.br/transparencia/prestacao-de-contas/transparencia-e-prestacao-de-contas">Prestação
# 						de Contas</a></li>
# 				<li class="nav-item"><a class="link link--nav"
# 					href="https://www12.senado.leg.br/transparencia/gestgov/HP-gestao-e-governanca">Gestão
# 						e Governança</a></li>
# 				<li class="nav-item"><a class="link link--nav"
# 					href="https://www12.senado.leg.br/transparencia/licitacoes-e-contratos/licitacoes-e-contratos">Licitações
# 						e Contratos</a></li>
# 				<li class="nav-item"><a class="link link--nav"
# 					href="https://www12.senado.leg.br/transparencia/rh/HP-recursos-humanos">Gestão
# 						de Pessoas</a></li>
# 				<li class="nav-item"><a class="link link--nav"
# 					href="https://www12.senado.leg.br/transparencia/orcamento-e-financas/orcamento-e-financas">Orçamento
# 						e Finanças</a></li>
# 				<li class="nav-item"><a class="link link--nav"
# 					href="https://www12.senado.leg.br/dados-abertos">Dados Abertos</a></li>
# 				<li class="nav-item dropdown"><a
# 					class="link link--nav dropdown-toggle" id="js-menu-1" href="#"
# 					data-toggle="dropdown.se" aria-haspopup="true"
# 					aria-expanded="false">Mais</a>
# 					<div class="dropdown-menu dropdown-menu--sf"
# 						aria-labelledby="js-menu-1">
# 						<a class="dropdown-item"
# 							href="https://www12.senado.leg.br/transparencia/leg/legislacao-relacionada">Legislação
# 							Relacionada</a> <a class="dropdown-item"
# 							href="https://www12.senado.leg.br/transparencia/indice-de-transparencia-legislativa">Índice
# 							de Transparência </a> <a class="dropdown-item"
# 							href="https://www12.senado.leg.br/perguntas-frequentes">Perguntas
# 							Frequentes</a> <a class="dropdown-item"
# 							href="https://www12.senado.leg.br/transparencia/ctcs/conselho-de-transparencia">Conselho
# 							de Transparencia</a> <a class="dropdown-item"
#                             href="https://www12.senado.leg.br/transparencia/sobre-1">Transparência Pública</a>
# 					</div></li>
# 			</ul>
# 		</div>
# 	</nav>
# </div>
#
# 	<div class="sf-component">
# 		<div class="sf-container">
# 			<ol class="Breadcrumbs">
# 				<li> <a
# 						href="https://www.senado.leg.br/transparencia/">Transparência</a>
# 				 </li>
# 				<li> <a
# 						href="https://www25.senado.leg.br/web/transparencia/sen/">Senadores</a>
# 				 </li>
# 				<li class="active"> Flávio Bolsonaro</li>
# 			</ol>
# 		</div>
# 	</div>
# 	<div class="aui">
# 			<!-- fragmento de quadro do senador -->
#
# 				<section class="conteudoBackground">
# 		<div class="ProfileSenadores">
# 			<div class="container bg">
# 				<div class="conteudo row">
# 					<div class="span12">
# 						<div class="head">
# 							<div class="span8 margin_ajust">
# 								<h1>
# 									<span>Flávio Bolsonaro - RJ</span>
# 									<img class="sf-senador-bandeira-uf"
# 										src="http://www.senado.leg.br/senadores/img/bandeiras/RJ_p.gif"
# 										alt="RJ" />
#
#
# 										<br />
# 										<small>
# 												Patriota
# 												(Líder)
#
# 										</small>
#
# 								</h1>
# 							</div>
# 							<div class="span4 margin_ajust">
#
# 									<div class="text-right periodo">Período 2019-2027</div>
#
# 							</div>
# 						</div>
# 					</div>
# 					<div class="clearFix"></div>
# 					<div class="span12">
# 						<div class="body">
# 							<div class="span3 margin_ajust">
# 								<div class="foto">
# 									<img
# 										src="https://www.senado.leg.br/senadores/img/fotos-oficiais/senador5894.jpg"
# 										alt="Flávio Bolsonaro" style="width: 240px;" />
# 								</div>
# 							</div>
# 							<div class="span9 margin_ajust">
# 								<div class="row">
# 									<div class="span9">
# 										<div class="bgblackOpacity">
# 											<div class="dadosPessoais">
# 												<h2>Dados Pessoais</h2>
# 												<dl class="dl-horizontal">
# 													<dt>Nome civil:</dt>
# 													<dd>Flávio Nantes Bolsonaro</dd>
#
# 													<dt>Data de Nascimento:</dt>
# 													<dd>30/04/1981</dd>
#
#
#
#
# 														<dt>Naturalidade:</dt>
# 														<dd>
# 															Rio de Janeiro
# 															(RJ)
# 														</dd>
#
#
#
# 														<dt>Gabinete:</dt>
# 														<dd>Senado Federal Anexo 1  17º Pavimento  </dd>
#
#
# 															<dt>Telefones:</dt>
# 															<dd>(61) 3303-1717 / 1718</dd>
#
#
#
#
#
# 															<dt>E-mail:</dt>
# 															<dd>
# 																<a href="mailto:sen.flaviobolsonaro@senado.leg.br">sen.flaviobolsonaro@senado.leg.br</a>
# 															</dd>
#
#
#
#
#
#
# 																	<dt>Escritório de apoio:</dt>
# 																	<dd>AVENIDA AFONSO ARINOS DE MELO FRANCO, 222. - BLOCO 2A - SALA 308. BARRA DA TIJUCA, RIO DE JANEIRO, RJ. CEP:22631-455</dd>
#
# 																	<dd>Telefone:(21) 3627-3800</dd>
#
#
#
#
# 												</dl>
# 											</div>
# 											<div class="botaoNavegacao">
# 												<a class="btn btn-mini btn-default" href="https://www25.senado.leg.br/web/atividade/materias/-/materia/autor/5894/p/1"
# 													title="Proposições">Proposições</a> <a
# 													class="btn btn-mini btn-default" href="https://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/parlamentar/5894"
# 													title="Pronunciamentos">Pronunciamentos</a>
#
# 													<a class="btn btn-mini btn-default" href="https://www25.senado.leg.br/web/atividade/materias/-/materia/relatadas/5894/p/1"
# 														title="Relatorias">Relatorias</a>
# 													<a class="btn btn-mini btn-default" href="https://www25.senado.leg.br/web/atividade/votacoes-nominais/-/v/parlamentar/Flávio Nantes Bolsonaro"
# 														title="Votações">Votações</a>
#
# 												<a class="btn btn-default" role="button"
# 													href="https://www25.senado.leg.br/web/senadores/senador/-/perfil/5894"> <i
# 													class="icon-plus-sign"></i> Página Institucional
# 												</a>
# 											</div>
# 										</div>
# 									</div>
# 								</div>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 			<!-- FIM CONTAINER BG -->
# 		</div>
# 	</section>
#
# 		</div>
# 	<section id="conteudoPrincipal" class="conteudo aui">
# 		<div class="container">
# 			<div>
# 					<div class="row-fluid">
# 						<aside class="span3">
# 							<div class="painel sen-painel-lateral">
# 								<div class="painel-cabecalho">Informações Relacionadas</div>
# 								<div class="painel-corpo">
# 									<ul class="unstyled">
# 										<li><a href="http://www.senado.leg.br/senadores">Portal
# 												dos Senadores</a></li>
#
# 										<li><a
# 											href="http://www12.senado.leg.br/transparencia/leg/legislacao-relacionada">Legislação
# 												Relacionada</a></li>
# 									</ul>
# 								</div>
# 								<div class="painel-rodape"></div>
# 							</div>
# 						</aside>
# 						<div id="conteudo_transparencia"
# 							class="span9 margin_ajust transp-sen-conteudo-principal">
#
# 					<h1 class="sen-conteudo-interno">Recursos Utilizados em 2021</h1>
# 					<div class="row">
# 						<div class="pull-left btn-informacoes">
# 							<a class="btn btn-default" target="blank"
# 								href="https://www12.senado.leg.br/transparencia/sen/informacoes-sobre-recursos-utilizados-pelos-senadores">
# 								Informações sobre a atualização dos dados </a>
# 						</div>
# 						<div class="sen-barra-filtro pull-right">
# 							<div class="form-inline">
#
# 		<div class="btn-group">
# 			<button type="button" class="btn btn-default dropdown-toggle"
# 				data-toggle="dropdown">
# 				Ver outro ano&nbsp;<span class="caret"></span>
# 			</button>
# 			<ul class="dropdown-menu" role="menu">
# 				<li><a
# 					href="https://www6g.senado.leg.br/transparencia/sen/5894/?ano=2019#conteudo_transparencia">2019</a></li>
# 				<li><a
# 					href="https://www6g.senado.leg.br/transparencia/sen/5894/?ano=2020#conteudo_transparencia">2020</a></li>
# 				<li><a
# 					href="https://www6g.senado.leg.br/transparencia/sen/5894/?ano=2021#conteudo_transparencia">2021</a></li>
#
#
#
# 			</ul>
# 			&nbsp;
# 		</div>
#
# 							</div>
# 						</div>
# 					</div>
# 					<div class="clear"></div>
# 					<div class="sen-conteudo-interno">
#
#
#
# 			<div class="accordion" id="accordion-ceaps">
# 				<div class="accordion-group accordion-caret">
# 					<div class="accordion-heading">
# 						<a class="accordion-toggle" data-toggle="collapse"
# 							data-parent="accordion-ceaps"
# 							href="#collapse-ceaps">Cotas para Exercício da Atividade Parlamentar</a>
# 					</div>
# 					<div id="collapse-ceaps" class="accordion-body collapse in">
# 						<div class="accordion-inner">
#
# 							<table class="table table-striped">
# 								<caption class="sr-only">Valores de Cotas para Exercício da Atividade Parlamentar</caption>
# 								<thead>
# 									<tr>
# 										<th>Recurso</th>
# 										<th class="valor">Valor</th>
# 									</tr>
# 								</thead>
# 								<tbody>
#
#
#
# 											<tr>
# 												<td
# 													title="Aluguel de imóveis para escritório político, compreendendo despesas concernentes a eles."><i
# 													class="icon-angle-right"></i>&nbsp;
# 													Aluguel de imóveis para escritório político&nbsp;
#
# 												</td>
# 												<td class="valor">
# 													<a href="ceaps/1/?ano=2021#conteudo_transparencia"
# 														title="Ver detalhe mês a mês de Aluguel de imóveis para escritório político"><span>23.417,86</span>
# 													</a>
#
#
# 												</td>
# 											</tr>
#
#
#
#
# 											<tr>
# 												<td
# 													title="Aquisição de material de consumo para uso no escritório político, inclusive aquisição ou locação de software, despesas postais, aquisição de publicações, locação de móveis e de equipamentos."><i
# 													class="icon-angle-right"></i>&nbsp;
# 													Aquisição de material de consumo&nbsp;
#
# 												</td>
# 												<td class="valor">
# 													<a href="ceaps/2/?ano=2021#conteudo_transparencia"
# 														title="Ver detalhe mês a mês de Aquisição de material de consumo"><span>35,10</span>
# 													</a>
#
#
# 												</td>
# 											</tr>
#
#
#
#
# 											<tr>
# 												<td
# 													title="Locomoção, hospedagem, alimentação, combustíveis e lubrificantes"><i
# 													class="icon-angle-right"></i>&nbsp;
# 													Locomoção, hospedagem, alimentação e combustíveis&nbsp;
#
# 												</td>
# 												<td class="valor">
# 													<a href="ceaps/3/?ano=2021#conteudo_transparencia"
# 														title="Ver detalhe mês a mês de Locomoção, hospedagem, alimentação e combustíveis"><span>0,00</span>
# 													</a>
#
#
# 												</td>
# 											</tr>
#
#
#
#
# 											<tr>
# 												<td
# 													title="Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar"><i
# 													class="icon-angle-right"></i>&nbsp;
# 													Contratação de serviços de apoio ao parlamentar&nbsp;
#
# 												</td>
# 												<td class="valor">
# 													<a href="ceaps/4/?ano=2021#conteudo_transparencia"
# 														title="Ver detalhe mês a mês de Contratação de serviços de apoio ao parlamentar"><span>0,00</span>
# 													</a>
#
#
# 												</td>
# 											</tr>
#
#
#
#
# 											<tr>
# 												<td
# 													title="Divulgação da atividade parlamentar"><i
# 													class="icon-angle-right"></i>&nbsp;
# 													Divulgação da atividade parlamentar&nbsp;
#
# 												</td>
# 												<td class="valor">
# 													<a href="ceaps/5/?ano=2021#conteudo_transparencia"
# 														title="Ver detalhe mês a mês de Divulgação da atividade parlamentar"><span>0,00</span>
# 													</a>
#
#
# 												</td>
# 											</tr>
#
#
#
#
# 											<tr>
# 												<td
# 													title="Passagens aéreas, aquáticas e terrestres nacionais"><i
# 													class="icon-angle-right"></i>&nbsp;
# 													Passagens aéreas, aquáticas e terrestres nacionais&nbsp;
#
# 												</td>
# 												<td class="valor">
# 													<a href="ceaps/8/?ano=2021#conteudo_transparencia"
# 														title="Ver detalhe mês a mês de Passagens aéreas, aquáticas e terrestres nacionais"><span>12.708,44</span>
# 													</a>
#
#
# 												</td>
# 											</tr>
#
#
#
#
# 											<tr>
# 												<td
# 													title="Serviços de Segurança Privada"><i
# 													class="icon-angle-right"></i>&nbsp;
# 													Serviços de Segurança Privada&nbsp;
#
# 												</td>
# 												<td class="valor">
# 													<a href="ceaps/9/?ano=2021#conteudo_transparencia"
# 														title="Ver detalhe mês a mês de Serviços de Segurança Privada"><span>0,00</span>
# 													</a>
#
#
# 												</td>
# 											</tr>
#
#
#
#
#
#
#
#
#
# 								</tbody>
# 								<tfoot>
# 									<tr>
# 										<td>Total</td>
# 										<td class="valor">36.161,40</td>
# 									</tr>
# 								</tfoot>
# 							</table>
# 							<span>Sistema Cotas - Dados de 27/08/2021 (Secretaria de Finanças, Orçamento e Contabilidade)</span>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
#
# 			<div class="accordion" id="accordion-outros-gastos">
# 				<div class="accordion-group accordion-caret">
# 					<div class="accordion-heading">
# 						<a class="accordion-toggle" data-toggle="collapse"
# 							data-parent="accordion-outros-gastos"
# 							href="#collapse-outros-gastos">Gastos não inclusos nas Cotas para Exercício da Atividade Parlamentar</a>
# 					</div>
# 					<div id="collapse-outros-gastos" class="accordion-body collapse in">
# 						<div class="accordion-inner">
#
# 							<table class="table table-striped">
# 								<caption class="sr-only">Valores de Gastos não inclusos nas Cotas para Exercício da Atividade Parlamentar</caption>
# 								<thead>
# 									<tr>
# 										<th>Recurso</th>
# 										<th class="valor">Valor</th>
# 									</tr>
# 								</thead>
# 								<tbody>
#
# 										<tr class="sen_tabela_linha_grupo">
# 											<td
# 												title="Despesas com Viagens Oficiais">Viagens Oficiais&nbsp;</td>
# 											<td class="valor"> 13.127,71</td>
# 										</tr>
#
# 											<tr>
# 												<td
# 													title="Diárias relacionadas a Viagens Oficiais"><i
# 													class="icon-angle-right"></i>&nbsp;
# 													Diárias&nbsp;
# 												<div class="fonte" style="text-align:justify;">
# 													<small> Obs.: As informações aqui disponibilizadas são atualizadas conforme o recebimento pelo Senado dos dados do Sistema Integrado de Administração Financeira do Governo Federal - SIAFI. Ordens bancárias de pagamento de diárias são exibidas após dois dias úteis da emissão. Ordens bancárias canceladas em dia posterior ao da emissão deixam de ser exibidas após o recebimento pelo Senado das informações de cancelamento do SIAFI. </small>
# 												</div>
# 												</td>
# 												<td class="valor">
# 													<a href="viagens/1/?ano=2021#conteudo_transparencia"
# 														title="Ver detalhe mês a mês de Diárias"><span>13.127,71</span>
# 													</a>
#
#
# 												</td>
# 											</tr>
#
#
#
#
# 											<tr>
# 												<td
# 													title="Ressarcimento de passagens relacionadas a Viagens Oficiais"><i
# 													class="icon-angle-right"></i>&nbsp;
# 													Ressarcimento de Passagens&nbsp;
#
# 												</td>
# 												<td class="valor">
# 													<a href="viagens/2/?ano=2021#conteudo_transparencia"
# 														title="Ver detalhe mês a mês de Ressarcimento de Passagens"><span>0,00</span>
# 													</a>
#
#
# 												</td>
# 											</tr>
#
# 												<tr>
# 													<td><i class="icon-angle-right"></i>&nbsp;&nbsp;Passagens emitidas</td>
# 													<td class="valor">
# 														<a href="https://www25.senado.leg.br/documents/16011/113705825/5894.pdf" target="_blank"> Consulte </a>
#
# 													</td>
# 												</tr>
#
#
#
#
#
#
#
# 										<tr class="sen_tabela_linha_grupo">
# 											<td
# 												title="Consumo de Material do Gabinete">Consumo de Material&nbsp;</td>
# 											<td class="valor"> 1.781,96</td>
# 										</tr>
#
# 											<tr>
# 												<td
# 													title="Combustíveis"><i
# 													class="icon-angle-right"></i>&nbsp;
# 													Combustíveis&nbsp;
#
# 												</td>
# 												<td class="valor">
#
# 													<a href="consumo/1/?ano=2021#conteudo_transparencia"
# 														title="Ver detalhe mês a mês de Combustíveis"><span>0,00</span>
# 													</a>
#
# 												</td>
# 											</tr>
#
#
#
#
# 											<tr>
# 												<td
# 													title="Outros materiais"><i
# 													class="icon-angle-right"></i>&nbsp;
# 													Outros materiais&nbsp;
#
# 												</td>
# 												<td class="valor">
# 													<a href="consumo/2/?ano=2021#conteudo_transparencia"
# 														title="Ver detalhe mês a mês de Outros materiais"><span>1.781,96</span>
# 													</a>
#
#
# 												</td>
# 											</tr>
#
#
#
#
#
#
#
#
#
# 										<tr class="sen_tabela_linha_grupo">
# 											<td
# 												title="Cotas Postais">Correios&nbsp;</td>
# 											<td class="valor"><a
# 												href="correios/?ano=2021#conteudo_transparencia"
# 												title="Ver detalhe mês a mês de Correios">21.157,43</a> </td>
# 										</tr>
#
#
#
#
#
#
#
#
#
#
#
# 								</tbody>
# 								<tfoot>
# 									<tr>
# 										<td>Total</td>
# 										<td class="valor">36.067,10</td>
# 									</tr>
# 								</tfoot>
# 							</table>
#
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
# 							<div class="accordion" id="accordion-outros">
# 								<div class="accordion-group accordion-caret">
# 									<div class="accordion-heading">
# 										<a class="accordion-toggle" data-toggle="collapse"
# 											data-parent="#accordion-outros" href="#collapse-outros">
# 											Benefícios </a>
# 									</div>
# 									<div id="collapse-outros" class="accordion-body collapse in">
# 										<div class="accordion-inner">
#
#
# 											<table class="table table-striped">
# 												<caption class="sr-only">Uso de Benefícios</caption>
# 												<thead>
# 													<tr>
# 														<th>Benefício</th>
# 														<th>Utilização</th>
# 													</tr>
# 												</thead>
# 												<tbody>
# 													<tr>
# 														<td>Auxílio-Moradia</td>
# 														<td>
#
#
# 																	Não utilizou.
#
#
# 															 </td>
# 													</tr>
# 													<tr>
# 														<td>Imóvel Funcional</td>
# 														<td>
#
#
# 																		<a href="beneficios/?numeroFuncional=341232&amp;ano=2021"
# 																			data-toggle="modal" data-target="#modalBeneficios">Utilizou (3 meses)</a>
#
#
#
#
# 															 </td>
# 													</tr>
# 												</tbody>
# 											</table>
# 											<div id="modalBeneficios" class="modal hide fade"
# 												tabindex="-1" role="dialog"
# 												aria-labelledby="modalBeneficiosLabel" aria-hidden="true">
# 												<div class="modal-header">
# 													<button type="button" class="close" data-dismiss="modal"
# 														aria-hidden="true">×</button>
# 													<h3 id="modalBeneficiosLabel">Uso de Benefícios</h3>
# 												</div>
# 												<div class="modal-body"></div>
# 												<div class="modal-footer">
# 													<button class="btn btn-primary" data-dismiss="modal"
# 														aria-hidden="true">Fechar</button>
# 												</div>
# 											</div>
# 										</div>
# 									</div>
# 								</div>
# 							</div>
# 							<div class="accordion" id="accordion-pessoal">
# 								<div class="accordion-group accordion-caret">
# 									<div class="accordion-heading">
# 										<a class="accordion-toggle" data-toggle="collapse"
# 											data-parent="#accordion-pessoal" href="#collapse-pessoal">
# 											Pessoal </a>
# 									</div>
# 									<div id="collapse-pessoal" class="accordion-body collapse in">
# 										<div class="accordion-inner">
#
# 											<table class="table table-striped">
# 												<caption class="sr-only">Quantidade de
# 													funcionários por local e vínculo</caption>
# 												<thead>
# 													<tr>
# 														<th>Local / Vínculo</th>
# 														<th class="valor">Quantidade</th>
# 													</tr>
# 												</thead>
# 												<tbody>
#
# 														<tr class="sen_tabela_linha_grupo">
# 															<td><span>Gabinete</span></td>
# 															<td class="valor"><a href="pessoal/?local=gabinete&amp;ano=2021&amp;vinculo=TODOS#conteudo_transparencia"
# 																title="Ver lista de funcionários no Gabinete">
# 																	19 pessoa(s)
#
# 															</a></td>
# 														</tr>
# 														<tr>
# 															<td><i class="icon-angle-right"></i>&nbsp;<span>Comissionados</span></td>
# 															<td class="valor"><a
# 																href="pessoal/?local=gabinete&amp;ano=2021&amp;vinculo=COMISSIONADO#conteudo_transparencia"
# 																title="Ver lista de Comissionados no Gabinete">
# 																	18 pessoa(s)
# 															</a></td>
# 														</tr>
# 														<tr>
# 															<td><i class="icon-angle-right"></i>&nbsp;<span>Efetivos</span></td>
# 															<td class="valor"><a
# 																href="pessoal/?local=gabinete&amp;ano=2021&amp;vinculo=EFETIVO#conteudo_transparencia"
# 																title="Ver lista de Efetivos no Gabinete">
# 																	1 pessoa(s)
# 															</a></td>
# 														</tr>
#
# 														<tr class="sen_tabela_linha_grupo">
# 															<td><span>Escritório(s) de Apoio</span></td>
# 															<td class="valor"><a href="pessoal/?local=escritorio&amp;ano=2021&amp;vinculo=TODOS#conteudo_transparencia"
# 																title="Ver lista de funcionários no Escritório(s) de Apoio">
# 																	4 pessoa(s)
#
# 															</a></td>
# 														</tr>
# 														<tr>
# 															<td><i class="icon-angle-right"></i>&nbsp;<span>Comissionados</span></td>
# 															<td class="valor"><a
# 																href="pessoal/?local=escritorio&amp;ano=2021&amp;vinculo=COMISSIONADO#conteudo_transparencia"
# 																title="Ver lista de Comissionados no Escritório(s) de Apoio">
# 																	4 pessoa(s)
# 															</a></td>
# 														</tr>
#
#
#
#
#
# 												</tbody>
# 											</table>
# 										</div>
# 									</div>
# 								</div>
# 							</div>
# 							<div class="accordion" id="accordion-subsidios">
# 								<div class="accordion-group accordion-caret">
# 									<div class="accordion-heading">
# 										<a class="accordion-toggle" data-toggle="collapse"
# 											data-parent="#accordion-subsidios" href="#collapse-subsidios">
# 											Subsídios e Aposentadoria </a>
# 									</div>
# 									<div id="collapse-subsidios" class="accordion-body collapse in">
# 										<div class="accordion-inner">
#
#
# 											<table class="table table-striped">
# 												<caption class="sr-only">Consulta de subsídios e
# 													aposentadoria</caption>
# 												<thead>
# 													<tr>
# 														<th>Recurso</th>
# 														<th>Consulta</th>
# 													</tr>
# 												</thead>
# 												<tbody>
# 													<tr>
# 														<td>Subsídios do Senador</td>
# 														<td><a href="https://www.senado.leg.br/transparencia/rh/servidores/detalhe.asp?fcodigo=3508803&amp;fvinculo=1" title="Ver subsídios do Senador">Consulte</a>
# 															</td>
# 													</tr>
#
# 												</tbody>
# 											</table>
# 											Para informações de aposentadoria de senadores, em qualquer
# 											período, acesse: <a href="https://www.senado.leg.br/transparencia/rh/servidores/consulta_senadores_aposentados.asp">Proventos
# 												de aposentadoria de Senadores</a>.
# 										</div>
# 									</div>
# 								</div>
# 							</div>
#
# 					</div>
#
# 						</div>
# 					</div>
# 				</div>
# 		</div>
# 	</section>
# 	<div class="sf-wrapper">
# 	<footer class="Footer">
# 		<div class="container">
# 			<div class="Triad Triad--stackable">
# 				<div class="Rail gamma my-2"><a class="link link-deep--facebook" href="https://www.facebook.com/SenadoFederal" title="Facebook" target="_blank"><i class="fab fa-facebook"></i></a><a class="link link-deep--twitter" href="https://twitter.com/senadofederal" title="Twitter" target="_blank"><i class="fab fa-twitter"></i></a><a class="link link-deep--instagram" href="https://www.instagram.com/senadofederal" title="Instagram" target="_blank"><i class="fab fa-instagram"></i></a><a class="link link-deep--youtube" href="https://www.youtube.com/user/TVSenadoOficial" title="Youtube" target="_blank"><i class="fab fa-youtube"></i></a></div>
# 				<div class="Rail my-2"><a href="https://www.camara.leg.br" title="Câmara dos Deputados" target="_blank"><img src="https://www.senado.leg.br/noticias/essencial/images/icon-camara.svg" alt="Câmara dos Deputados"/></a><a href="https://www.congressonacional.leg.br" title="Congresso Nacional" target="_blank"><img src="https://www.senado.leg.br/noticias/essencial/images/icon-congresso.svg" alt="Congresso Nacional"/></a><a href="https://www.tcu.gov.br" title="Tribunal de Contas da União" target="_blank"><img src="https://www.senado.leg.br/noticias/essencial/images/icon-tcu.svg" alt="Tribunal de Contas da União"/></a></div>
# 				<div class="Rail Rail--fenced my-2"><a class="link link-deep" href="https://www12.senado.leg.br/institucional/carta-de-servicos/en/carta-de-servicos">ENGLISH</a><a class="link link-deep" href="https://www12.senado.leg.br/institucional/carta-de-servicos/es/carta-de-servicos">ESPAÑOL</a><a class="link link-deep" href="https://www12.senado.leg.br/institucional/carta-de-servicos/fr/carta-de-servicos">FRANÇAIS</a></div>
# 			</div>
# 			<div class="divider my-2"></div>
# 			<div class="Triad Triad--stackable">
# 				<div class="my-2"><a class="link link-deep" href="https://intranet.senado.leg.br" title="Intranet"><i class="fas fa-lock mr-1"></i>  Intranet</a></div>
# 				<div class="Rail Rail--fenced Rail--stackable my-2"><a class="link link-deep" href="https://www12.senado.leg.br/institucional/pessoas/pessoas">Servidor efetivo</a><a class="link link-deep" href="https://www12.senado.leg.br/institucional/pessoas/pessoas">Servidor comissionado</a><a class="link link-deep" href="https://www12.senado.leg.br/institucional/pessoas/pessoas">Servidor aposentado</a><a class="link link-deep" href="https://www12.senado.leg.br/institucional/pessoas/pessoas">Pensionista</a></div>
# 				<div class="my-2"><a class="link link-deep" href="https://www12.senado.leg.br/institucional/falecomosenado" title="fale com o Senado"><i class="fas fa-phone u-flip-x mr-1"></i>  Fale com o Senado</a></div>
# 			</div>
# 			<div class="divider my-2"></div>
# 			<div class="d-flex justify-content-xl-center"><span class="my-2">Senado Federal - Praça dos Três Poderes - Brasília DF - CEP 70165-900 |  <span class="text-nowrap">Telefone: 0800 0 61 2211</span></span></div>
# 		</div>
# 	</footer>
# </div>
#
#
# 	<script type="text/javascript"
# 		src="/transparencia/lib/jquery/jquery-1.12.4.min-4f252523d4af0b478c810c2547a63e19.js"></script>
# 	<script type="text/javascript" src="/transparencia/lib/bootstrap-2.3.2/js/bootstrap.min-bed31fb959612a0a77d8e87b9d0b3683.js"></script>
# 	<script type="text/javascript"
# 		src="/transparencia/lib/bootstrap-datepicker/bootstrap-datepicker-c4d744b227a1abd042c92f04a2a310e1.js"></script>
# 	<script type="text/javascript"
# 		src="/transparencia/lib/bootstrap-datepicker/locales/bootstrap-datepicker.pt-BR-2b702f10c90440a1bd15133ae9768bd0.js"></script>
# 	<script type="text/javascript"
# 		src="/transparencia/lib/essencial-2020/js/essencial-0528b73cc844243c240e73b71c2427aa.js"></script>
# 	<script type="text/javascript" src="/transparencia/lib/jstree/jstree.min-533a703cea4af4a8420a6d1dac814701.js"></script>
# 	<script type="text/javascript" src="/transparencia/js/tooltip-05f7c672357109ce997e219ca757eada.js"></script>
# 	<script type="text/javascript" src="/transparencia/js/arvore-orgao-f6b4694f232c53b617f5b7ffe8ca5e63.js"></script>
#
#
#
# 	<div style="display: none;">versão: portal-transparencia - 1.8.14</div>
# </body>
#
# </html>

# %% [markdown]
# Agora que temos o código-fonte salvo na variável `site`, usamos BeautifulSoup para fazer o _parsing_, ou seja, compreender a estrutura. Vamos dar à biblioteca o apelido de `bs`.

# %%
from bs4 import BeautifulSoup as bs

# %% [markdown]
# Com a biblioteca carregada, vamos salvar `site.content` com _parsing_ na variável `content`.

# %%
content = bs(site.content, "html.parser")
# Documentação: https://www.crummy.com/software/BeautifulSoup/bs4/doc/#making-the-soup

print(content)
# Out:
# <!DOCTYPE html>
#
# <html lang="pt-br">
# <head>
# <title>Recursos Utilizados por
# 	Flávio Bolsonaro em
# 	2021 - Transparência</title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Senado Federal" name="author"/>
# <link href="/transparencia/img/senado/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/transparencia/img/senado/icones-tablet/16x16.png" rel="icon" type="image/png"/>
# <link href="/transparencia/img/senado/icones-tablet/114x114.png" rel="apple-touch-icon" type="image/png"/>
# <link href="/transparencia/img/senado/icones-tablet/96x96.png" rel="apple-touch-icon-precomposed" type="image/png"/>
# <link href="/transparencia/lib/bootstrap-2.3.2/css/bootstrap.min-282663d1dc8a60dcef58304c09005aa5.css" rel="stylesheet" type="text/css"/>
# <link href="/transparencia/lib/bootstrap-2.3.2/css/bootstrap-responsive-d2c30d07a98d50e945570bf32c56435f.css" rel="stylesheet" type="text/css"/>
# <link href="/transparencia/lib/shell/css/shell-b0aaf685987835264626af667fc80597.css" rel="stylesheet" type="text/css"/>
# <link href="/transparencia/lib/essencial/fat-1282afbf332d5327ecb1ae75e9f114b7.css" rel="stylesheet" type="text/css"/>
# <link href="/transparencia/lib/shell/css/fix-aui-e66c089b905efe6fed9373f7316201e0.css" rel="stylesheet" type="text/css"/>
# <link href="/transparencia/lib/shell/css/painel-ffedaf873ba1ce691e8dbb61f73db776.css" rel="stylesheet" type="text/css"/>
# <link href="/transparencia/lib/shell/css/panel-6ad856905c386078b7078dd6b9382fb7.css" rel="stylesheet" type="text/css"/>
# <link href="/transparencia/lib/shell/css/titulos-d964796b4642a6c84d84357451b6adb1.css" rel="stylesheet" type="text/css"/>
# <link href="/transparencia/css/font-awesome/css/font-awesome-2d53b06f292dcb355b5e1a39ec065054.css" rel="stylesheet" type="text/css"/>
# <link href="/transparencia/lib/bootstrap-datepicker/bootstrap-datepicker-1ff9dc961628101b7a2c5fd77c66ecc3.css" rel="stylesheet" type="text/css"/>
# <link href="/transparencia/lib/jstree/themes/default/style-ec61aa001430a9bf505b7842e4d7a05f.css" rel="stylesheet" type="text/css"/>
# <link href="/transparencia/css/transparencia-31623ffc97b79093f32a490d992180b8.css" rel="stylesheet" type="text/css"/>
# <link href="/transparencia/css/senadores-20677867d831fb0e6528b70006b5ca84.css" rel="stylesheet" type="text/css"/>
# <link href="/transparencia/lib/essencial-2020/css/essencial-2a517bbd35b9c42efee45151245150c8.css" rel="stylesheet" type="text/css"/>
# <link href="/transparencia/lib/essencial-2020/css/essencial-fix-bs2-e09537266d2f37581f77ef345b0a0d29.css" rel="stylesheet" type="text/css"/>
# <script>
# 				window.ga = window.ga || function() {
# 					(ga.q = ga.q || []).push(arguments)
# 				};
# 				ga.l = +new Date;
# 				ga('create', 'UA-27295293-6', 'auto');
# 				ga('create', 'UA-101435193-1', 'auto', 'global', {
# 					'alwaysSendReferrer' : true
# 				});
# 				ga('send', 'pageview');
# 				ga('global.send', 'pageview');
# 			</script>
# <script async="async" src="https://www.google-analytics.com/analytics.js"></script>
# <meta content="Resumo de recursos utilizados por [[Flávio Bolsonaro]] em	[[2021]]" name="description"/>
# <meta content="senado federal, transparência, despesas, senadores" name="keywords"/>
# <meta content="index, follow" name="robots"/>
# <meta content="2021" name="sf_ano"/>
# <meta content="Flávio Bolsonaro" name="sf_senador"/>
# </head>
# <body class="">
# <a class="sr-only" href="#conteudoPrincipal">Ir para conteúdo
# 		principal</a>
# <div class="sf-wrapper">
# <div class="js-sidebar-mountpoint" data-url="https://www12.senado.leg.br/hpsenado/wssidebar.json"></div>
# </div>
# <div class="sf-wrapper">
# <nav class="Triad navbar_global">
# <div>
# <button class="btn btn-lg btn-secondary js-sidebar-action" id="jstoggle" type="button">
# <i class="fas fa-bars"></i><span class="u-hideLower title-n">
# 					Menu</span>
# </button>
# </div>
# <div><a class="navbar_global-brand" href="https://www.senado.leg.br" title="Senado Federal"><img alt="Senado Federal" src="https://www.senado.leg.br/noticias/essencial/images/senado.svg"/></a>
# </div>
# <div>
# <div class="Rail Rail--fenced u-hideLower">
# <a class="js-vlibras" role="button" title="acessibilidade">
# <img src="https://www.senado.leg.br/noticias/essencial/images/hands.svg" width="25px"/></a><a class="link link-deep" href="https://www12.senado.leg.br/institucional/responsabilidade-social/acessibilidade/pages/acessibilidade-no-portal-do-senado">Acessibilidade</a><a class="link link-deep" href="http://www12.senado.gov.br/institucional/falecomosenado">Fale
# 					com o Senado</a>
# </div>
# <a class="btn btn-lg btn-secondary u-hideUpper" href="http://www12.senado.gov.br/institucional/falecomosenado"><i class="fas fa-phone"></i></a>
# </div>
# </nav>
# </div>
# <div class="sf-wrapper">
# <div class="menu-local">
# <div class="pt-2">
# <a class="nav_control-title d-none" href="#" title="Logo Portal"></a>
# <div class="nav_control-title">
# <h1><a href="https://www12.senado.leg.br/transparencia">Transparência</a>
# <span class="next-title">
# <a href="https://www25.senado.leg.br/web/transparencia/sen">Senadores</a>
# </span>
# </h1>
# </div>
# </div>
# <button aria-controls="menu-local__form" aria-expanded="false" aria-label="Exibe busca" class="btn_control-res btn btn-tertiary btn-lg" data-target="#menu-local__form" data-toggle="collapse.se" type="button">
# <i class="fas fa-search"></i>
# </button>
# <form action="https://www6g.senado.leg.br/busca/" class="menu-local__form collapse" id="menu-local__form" method="GET">
# <input name="portal" type="hidden" value="Transparência"/>
# <div class="search-wrapper">
# <input class="form-control search-out" name="q" placeholder="Buscar" type="search"/>
# <button class="search-btn" type="submit">
# <i class="fas fa-search"></i>
# </button>
# </div>
# </form>
# </div>
# </div>
# <div class="sf-wrapper">
# <nav class="navbar navbar_control navbar-expand-lg navbar--sf">
# <div aria-controls="js-navbar-dropdown" aria-expanded="false" aria-label="Exibe navegação" class="navbar-toggler navbar-toggler--sf" data-target="#js-navbar-dropdown" data-toggle="collapse.se" role="button">
# <button class="btn btn-secondary">
# <i class="fas fa-bars"></i>
# </button>
# <div class="ml-2">MENU DESTA SEÇÃO</div>
# </div>
# <div class="collapse navbar-collapse-se" id="js-navbar-dropdown">
# <ul class="navbar-nav navbar-nav--sf">
# <li class="nav-item"><a class="link link--nav" href="https://www25.senado.leg.br/web/transparencia/sen">Senadores</a></li>
# <li class="nav-item"><a class="link link--nav" href="https://www12.senado.leg.br/transparencia/prestacao-de-contas/transparencia-e-prestacao-de-contas">Prestação
# 						de Contas</a></li>
# <li class="nav-item"><a class="link link--nav" href="https://www12.senado.leg.br/transparencia/gestgov/HP-gestao-e-governanca">Gestão
# 						e Governança</a></li>
# <li class="nav-item"><a class="link link--nav" href="https://www12.senado.leg.br/transparencia/licitacoes-e-contratos/licitacoes-e-contratos">Licitações
# 						e Contratos</a></li>
# <li class="nav-item"><a class="link link--nav" href="https://www12.senado.leg.br/transparencia/rh/HP-recursos-humanos">Gestão
# 						de Pessoas</a></li>
# <li class="nav-item"><a class="link link--nav" href="https://www12.senado.leg.br/transparencia/orcamento-e-financas/orcamento-e-financas">Orçamento
# 						e Finanças</a></li>
# <li class="nav-item"><a class="link link--nav" href="https://www12.senado.leg.br/dados-abertos">Dados Abertos</a></li>
# <li class="nav-item dropdown"><a aria-expanded="false" aria-haspopup="true" class="link link--nav dropdown-toggle" data-toggle="dropdown.se" href="#" id="js-menu-1">Mais</a>
# <div aria-labelledby="js-menu-1" class="dropdown-menu dropdown-menu--sf">
# <a class="dropdown-item" href="https://www12.senado.leg.br/transparencia/leg/legislacao-relacionada">Legislação
# 							Relacionada</a> <a class="dropdown-item" href="https://www12.senado.leg.br/transparencia/indice-de-transparencia-legislativa">Índice
# 							de Transparência </a> <a class="dropdown-item" href="https://www12.senado.leg.br/perguntas-frequentes">Perguntas
# 							Frequentes</a> <a class="dropdown-item" href="https://www12.senado.leg.br/transparencia/ctcs/conselho-de-transparencia">Conselho
# 							de Transparencia</a> <a class="dropdown-item" href="https://www12.senado.leg.br/transparencia/sobre-1">Transparência Pública</a>
# </div></li>
# </ul>
# </div>
# </nav>
# </div>
# <div class="sf-component">
# <div class="sf-container">
# <ol class="Breadcrumbs">
# <li> <a href="https://www.senado.leg.br/transparencia/">Transparência</a>
# </li>
# <li> <a href="https://www25.senado.leg.br/web/transparencia/sen/">Senadores</a>
# </li>
# <li class="active"> Flávio Bolsonaro</li>
# </ol>
# </div>
# </div>
# <div class="aui">
# <!-- fragmento de quadro do senador -->
# <section class="conteudoBackground">
# <div class="ProfileSenadores">
# <div class="container bg">
# <div class="conteudo row">
# <div class="span12">
# <div class="head">
# <div class="span8 margin_ajust">
# <h1>
# <span>Flávio Bolsonaro - RJ</span>
# <img alt="RJ" class="sf-senador-bandeira-uf" src="http://www.senado.leg.br/senadores/img/bandeiras/RJ_p.gif"/>
# <br/>
# <small>
# 												Patriota
# 												(Líder)
#
# 										</small>
# </h1>
# </div>
# <div class="span4 margin_ajust">
# <div class="text-right periodo">Período 2019-2027</div>
# </div>
# </div>
# </div>
# <div class="clearFix"></div>
# <div class="span12">
# <div class="body">
# <div class="span3 margin_ajust">
# <div class="foto">
# <img alt="Flávio Bolsonaro" src="https://www.senado.leg.br/senadores/img/fotos-oficiais/senador5894.jpg" style="width: 240px;"/>
# </div>
# </div>
# <div class="span9 margin_ajust">
# <div class="row">
# <div class="span9">
# <div class="bgblackOpacity">
# <div class="dadosPessoais">
# <h2>Dados Pessoais</h2>
# <dl class="dl-horizontal">
# <dt>Nome civil:</dt>
# <dd>Flávio Nantes Bolsonaro</dd>
# <dt>Data de Nascimento:</dt>
# <dd>30/04/1981</dd>
# <dt>Naturalidade:</dt>
# <dd>
# 															Rio de Janeiro
# 															(RJ)
# 														</dd>
# <dt>Gabinete:</dt>
# <dd>Senado Federal Anexo 1  17º Pavimento  </dd>
# <dt>Telefones:</dt>
# <dd>(61) 3303-1717 / 1718</dd>
# <dt>E-mail:</dt>
# <dd>
# <a href="mailto:sen.flaviobolsonaro@senado.leg.br">sen.flaviobolsonaro@senado.leg.br</a>
# </dd>
# <dt>Escritório de apoio:</dt>
# <dd>AVENIDA AFONSO ARINOS DE MELO FRANCO, 222. - BLOCO 2A - SALA 308. BARRA DA TIJUCA, RIO DE JANEIRO, RJ. CEP:22631-455</dd>
# <dd>Telefone:(21) 3627-3800</dd>
# </dl>
# </div>
# <div class="botaoNavegacao">
# <a class="btn btn-mini btn-default" href="https://www25.senado.leg.br/web/atividade/materias/-/materia/autor/5894/p/1" title="Proposições">Proposições</a> <a class="btn btn-mini btn-default" href="https://www25.senado.leg.br/web/atividade/pronunciamentos/-/p/parlamentar/5894" title="Pronunciamentos">Pronunciamentos</a>
# <a class="btn btn-mini btn-default" href="https://www25.senado.leg.br/web/atividade/materias/-/materia/relatadas/5894/p/1" title="Relatorias">Relatorias</a>
# <a class="btn btn-mini btn-default" href="https://www25.senado.leg.br/web/atividade/votacoes-nominais/-/v/parlamentar/Flávio Nantes Bolsonaro" title="Votações">Votações</a>
# <a class="btn btn-default" href="https://www25.senado.leg.br/web/senadores/senador/-/perfil/5894" role="button"> <i class="icon-plus-sign"></i> Página Institucional
# 												</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- FIM CONTAINER BG -->
# </div>
# </section>
# </div>
# <section class="conteudo aui" id="conteudoPrincipal">
# <div class="container">
# <div>
# <div class="row-fluid">
# <aside class="span3">
# <div class="painel sen-painel-lateral">
# <div class="painel-cabecalho">Informações Relacionadas</div>
# <div class="painel-corpo">
# <ul class="unstyled">
# <li><a href="http://www.senado.leg.br/senadores">Portal
# 												dos Senadores</a></li>
# <li><a href="http://www12.senado.leg.br/transparencia/leg/legislacao-relacionada">Legislação
# 												Relacionada</a></li>
# </ul>
# </div>
# <div class="painel-rodape"></div>
# </div>
# </aside>
# <div class="span9 margin_ajust transp-sen-conteudo-principal" id="conteudo_transparencia">
# <h1 class="sen-conteudo-interno">Recursos Utilizados em 2021</h1>
# <div class="row">
# <div class="pull-left btn-informacoes">
# <a class="btn btn-default" href="https://www12.senado.leg.br/transparencia/sen/informacoes-sobre-recursos-utilizados-pelos-senadores" target="blank">
# 								Informações sobre a atualização dos dados </a>
# </div>
# <div class="sen-barra-filtro pull-right">
# <div class="form-inline">
# <div class="btn-group">
# <button class="btn btn-default dropdown-toggle" data-toggle="dropdown" type="button">
# 				Ver outro ano <span class="caret"></span>
# </button>
# <ul class="dropdown-menu" role="menu">
# <li><a href="https://www6g.senado.leg.br/transparencia/sen/5894/?ano=2019#conteudo_transparencia">2019</a></li>
# <li><a href="https://www6g.senado.leg.br/transparencia/sen/5894/?ano=2020#conteudo_transparencia">2020</a></li>
# <li><a href="https://www6g.senado.leg.br/transparencia/sen/5894/?ano=2021#conteudo_transparencia">2021</a></li>
# </ul>
#
# 		</div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# <div class="sen-conteudo-interno">
# <div class="accordion" id="accordion-ceaps">
# <div class="accordion-group accordion-caret">
# <div class="accordion-heading">
# <a class="accordion-toggle" data-parent="accordion-ceaps" data-toggle="collapse" href="#collapse-ceaps">Cotas para Exercício da Atividade Parlamentar</a>
# </div>
# <div class="accordion-body collapse in" id="collapse-ceaps">
# <div class="accordion-inner">
# <table class="table table-striped">
# <caption class="sr-only">Valores de Cotas para Exercício da Atividade Parlamentar</caption>
# <thead>
# <tr>
# <th>Recurso</th>
# <th class="valor">Valor</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td title="Aluguel de imóveis para escritório político, compreendendo despesas concernentes a eles."><i class="icon-angle-right"></i>
# 													Aluguel de imóveis para escritório político
#
# 												</td>
# <td class="valor">
# <a href="ceaps/1/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Aluguel de imóveis para escritório político"><span>23.417,86</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Aquisição de material de consumo para uso no escritório político, inclusive aquisição ou locação de software, despesas postais, aquisição de publicações, locação de móveis e de equipamentos."><i class="icon-angle-right"></i>
# 													Aquisição de material de consumo
#
# 												</td>
# <td class="valor">
# <a href="ceaps/2/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Aquisição de material de consumo"><span>35,10</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Locomoção, hospedagem, alimentação, combustíveis e lubrificantes"><i class="icon-angle-right"></i>
# 													Locomoção, hospedagem, alimentação e combustíveis
#
# 												</td>
# <td class="valor">
# <a href="ceaps/3/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Locomoção, hospedagem, alimentação e combustíveis"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar"><i class="icon-angle-right"></i>
# 													Contratação de serviços de apoio ao parlamentar
#
# 												</td>
# <td class="valor">
# <a href="ceaps/4/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Contratação de serviços de apoio ao parlamentar"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Divulgação da atividade parlamentar"><i class="icon-angle-right"></i>
# 													Divulgação da atividade parlamentar
#
# 												</td>
# <td class="valor">
# <a href="ceaps/5/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Divulgação da atividade parlamentar"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Passagens aéreas, aquáticas e terrestres nacionais"><i class="icon-angle-right"></i>
# 													Passagens aéreas, aquáticas e terrestres nacionais
#
# 												</td>
# <td class="valor">
# <a href="ceaps/8/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Passagens aéreas, aquáticas e terrestres nacionais"><span>12.708,44</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Serviços de Segurança Privada"><i class="icon-angle-right"></i>
# 													Serviços de Segurança Privada
#
# 												</td>
# <td class="valor">
# <a href="ceaps/9/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Serviços de Segurança Privada"><span>0,00</span>
# </a>
# </td>
# </tr>
# </tbody>
# <tfoot>
# <tr>
# <td>Total</td>
# <td class="valor">36.161,40</td>
# </tr>
# </tfoot>
# </table>
# <span>Sistema Cotas - Dados de 27/08/2021 (Secretaria de Finanças, Orçamento e Contabilidade)</span>
# </div>
# </div>
# </div>
# </div>
# <div class="accordion" id="accordion-outros-gastos">
# <div class="accordion-group accordion-caret">
# <div class="accordion-heading">
# <a class="accordion-toggle" data-parent="accordion-outros-gastos" data-toggle="collapse" href="#collapse-outros-gastos">Gastos não inclusos nas Cotas para Exercício da Atividade Parlamentar</a>
# </div>
# <div class="accordion-body collapse in" id="collapse-outros-gastos">
# <div class="accordion-inner">
# <table class="table table-striped">
# <caption class="sr-only">Valores de Gastos não inclusos nas Cotas para Exercício da Atividade Parlamentar</caption>
# <thead>
# <tr>
# <th>Recurso</th>
# <th class="valor">Valor</th>
# </tr>
# </thead>
# <tbody>
# <tr class="sen_tabela_linha_grupo">
# <td title="Despesas com Viagens Oficiais">Viagens Oficiais </td>
# <td class="valor"> 13.127,71</td>
# </tr>
# <tr>
# <td title="Diárias relacionadas a Viagens Oficiais"><i class="icon-angle-right"></i>
# 													Diárias
# 												<div class="fonte" style="text-align:justify;">
# <small> Obs.: As informações aqui disponibilizadas são atualizadas conforme o recebimento pelo Senado dos dados do Sistema Integrado de Administração Financeira do Governo Federal - SIAFI. Ordens bancárias de pagamento de diárias são exibidas após dois dias úteis da emissão. Ordens bancárias canceladas em dia posterior ao da emissão deixam de ser exibidas após o recebimento pelo Senado das informações de cancelamento do SIAFI. </small>
# </div>
# </td>
# <td class="valor">
# <a href="viagens/1/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Diárias"><span>13.127,71</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Ressarcimento de passagens relacionadas a Viagens Oficiais"><i class="icon-angle-right"></i>
# 													Ressarcimento de Passagens
#
# 												</td>
# <td class="valor">
# <a href="viagens/2/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Ressarcimento de Passagens"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td><i class="icon-angle-right"></i>  Passagens emitidas</td>
# <td class="valor">
# <a href="https://www25.senado.leg.br/documents/16011/113705825/5894.pdf" target="_blank"> Consulte </a>
# </td>
# </tr>
# <tr class="sen_tabela_linha_grupo">
# <td title="Consumo de Material do Gabinete">Consumo de Material </td>
# <td class="valor"> 1.781,96</td>
# </tr>
# <tr>
# <td title="Combustíveis"><i class="icon-angle-right"></i>
# 													Combustíveis
#
# 												</td>
# <td class="valor">
# <a href="consumo/1/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Combustíveis"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Outros materiais"><i class="icon-angle-right"></i>
# 													Outros materiais
#
# 												</td>
# <td class="valor">
# <a href="consumo/2/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Outros materiais"><span>1.781,96</span>
# </a>
# </td>
# </tr>
# <tr class="sen_tabela_linha_grupo">
# <td title="Cotas Postais">Correios </td>
# <td class="valor"><a href="correios/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Correios">21.157,43</a> </td>
# </tr>
# </tbody>
# <tfoot>
# <tr>
# <td>Total</td>
# <td class="valor">36.067,10</td>
# </tr>
# </tfoot>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="accordion" id="accordion-outros">
# <div class="accordion-group accordion-caret">
# <div class="accordion-heading">
# <a class="accordion-toggle" data-parent="#accordion-outros" data-toggle="collapse" href="#collapse-outros">
# 											Benefícios </a>
# </div>
# <div class="accordion-body collapse in" id="collapse-outros">
# <div class="accordion-inner">
# <table class="table table-striped">
# <caption class="sr-only">Uso de Benefícios</caption>
# <thead>
# <tr>
# <th>Benefício</th>
# <th>Utilização</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Auxílio-Moradia</td>
# <td>
#
#
# 																	Não utilizou.
#
#
# 															 </td>
# </tr>
# <tr>
# <td>Imóvel Funcional</td>
# <td>
# <a data-target="#modalBeneficios" data-toggle="modal" href="beneficios/?numeroFuncional=341232&amp;ano=2021">Utilizou (3 meses)</a>
# </td>
# </tr>
# </tbody>
# </table>
# <div aria-hidden="true" aria-labelledby="modalBeneficiosLabel" class="modal hide fade" id="modalBeneficios" role="dialog" tabindex="-1">
# <div class="modal-header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# <h3 id="modalBeneficiosLabel">Uso de Benefícios</h3>
# </div>
# <div class="modal-body"></div>
# <div class="modal-footer">
# <button aria-hidden="true" class="btn btn-primary" data-dismiss="modal">Fechar</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="accordion" id="accordion-pessoal">
# <div class="accordion-group accordion-caret">
# <div class="accordion-heading">
# <a class="accordion-toggle" data-parent="#accordion-pessoal" data-toggle="collapse" href="#collapse-pessoal">
# 											Pessoal </a>
# </div>
# <div class="accordion-body collapse in" id="collapse-pessoal">
# <div class="accordion-inner">
# <table class="table table-striped">
# <caption class="sr-only">Quantidade de
# 													funcionários por local e vínculo</caption>
# <thead>
# <tr>
# <th>Local / Vínculo</th>
# <th class="valor">Quantidade</th>
# </tr>
# </thead>
# <tbody>
# <tr class="sen_tabela_linha_grupo">
# <td><span>Gabinete</span></td>
# <td class="valor"><a href="pessoal/?local=gabinete&amp;ano=2021&amp;vinculo=TODOS#conteudo_transparencia" title="Ver lista de funcionários no Gabinete">
# 																	19 pessoa(s)
#
# 															</a></td>
# </tr>
# <tr>
# <td><i class="icon-angle-right"></i> <span>Comissionados</span></td>
# <td class="valor"><a href="pessoal/?local=gabinete&amp;ano=2021&amp;vinculo=COMISSIONADO#conteudo_transparencia" title="Ver lista de Comissionados no Gabinete">
# 																	18 pessoa(s)
# 															</a></td>
# </tr>
# <tr>
# <td><i class="icon-angle-right"></i> <span>Efetivos</span></td>
# <td class="valor"><a href="pessoal/?local=gabinete&amp;ano=2021&amp;vinculo=EFETIVO#conteudo_transparencia" title="Ver lista de Efetivos no Gabinete">
# 																	1 pessoa(s)
# 															</a></td>
# </tr>
# <tr class="sen_tabela_linha_grupo">
# <td><span>Escritório(s) de Apoio</span></td>
# <td class="valor"><a href="pessoal/?local=escritorio&amp;ano=2021&amp;vinculo=TODOS#conteudo_transparencia" title="Ver lista de funcionários no Escritório(s) de Apoio">
# 																	4 pessoa(s)
#
# 															</a></td>
# </tr>
# <tr>
# <td><i class="icon-angle-right"></i> <span>Comissionados</span></td>
# <td class="valor"><a href="pessoal/?local=escritorio&amp;ano=2021&amp;vinculo=COMISSIONADO#conteudo_transparencia" title="Ver lista de Comissionados no Escritório(s) de Apoio">
# 																	4 pessoa(s)
# 															</a></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# <div class="accordion" id="accordion-subsidios">
# <div class="accordion-group accordion-caret">
# <div class="accordion-heading">
# <a class="accordion-toggle" data-parent="#accordion-subsidios" data-toggle="collapse" href="#collapse-subsidios">
# 											Subsídios e Aposentadoria </a>
# </div>
# <div class="accordion-body collapse in" id="collapse-subsidios">
# <div class="accordion-inner">
# <table class="table table-striped">
# <caption class="sr-only">Consulta de subsídios e
# 													aposentadoria</caption>
# <thead>
# <tr>
# <th>Recurso</th>
# <th>Consulta</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Subsídios do Senador</td>
# <td><a href="https://www.senado.leg.br/transparencia/rh/servidores/detalhe.asp?fcodigo=3508803&amp;fvinculo=1" title="Ver subsídios do Senador">Consulte</a>
# </td>
# </tr>
# </tbody>
# </table>
# 											Para informações de aposentadoria de senadores, em qualquer
# 											período, acesse: <a href="https://www.senado.leg.br/transparencia/rh/servidores/consulta_senadores_aposentados.asp">Proventos
# 												de aposentadoria de Senadores</a>.
# 										</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div class="sf-wrapper">
# <footer class="Footer">
# <div class="container">
# <div class="Triad Triad--stackable">
# <div class="Rail gamma my-2"><a class="link link-deep--facebook" href="https://www.facebook.com/SenadoFederal" target="_blank" title="Facebook"><i class="fab fa-facebook"></i></a><a class="link link-deep--twitter" href="https://twitter.com/senadofederal" target="_blank" title="Twitter"><i class="fab fa-twitter"></i></a><a class="link link-deep--instagram" href="https://www.instagram.com/senadofederal" target="_blank" title="Instagram"><i class="fab fa-instagram"></i></a><a class="link link-deep--youtube" href="https://www.youtube.com/user/TVSenadoOficial" target="_blank" title="Youtube"><i class="fab fa-youtube"></i></a></div>
# <div class="Rail my-2"><a href="https://www.camara.leg.br" target="_blank" title="Câmara dos Deputados"><img alt="Câmara dos Deputados" src="https://www.senado.leg.br/noticias/essencial/images/icon-camara.svg"/></a><a href="https://www.congressonacional.leg.br" target="_blank" title="Congresso Nacional"><img alt="Congresso Nacional" src="https://www.senado.leg.br/noticias/essencial/images/icon-congresso.svg"/></a><a href="https://www.tcu.gov.br" target="_blank" title="Tribunal de Contas da União"><img alt="Tribunal de Contas da União" src="https://www.senado.leg.br/noticias/essencial/images/icon-tcu.svg"/></a></div>
# <div class="Rail Rail--fenced my-2"><a class="link link-deep" href="https://www12.senado.leg.br/institucional/carta-de-servicos/en/carta-de-servicos">ENGLISH</a><a class="link link-deep" href="https://www12.senado.leg.br/institucional/carta-de-servicos/es/carta-de-servicos">ESPAÑOL</a><a class="link link-deep" href="https://www12.senado.leg.br/institucional/carta-de-servicos/fr/carta-de-servicos">FRANÇAIS</a></div>
# </div>
# <div class="divider my-2"></div>
# <div class="Triad Triad--stackable">
# <div class="my-2"><a class="link link-deep" href="https://intranet.senado.leg.br" title="Intranet"><i class="fas fa-lock mr-1"></i>  Intranet</a></div>
# <div class="Rail Rail--fenced Rail--stackable my-2"><a class="link link-deep" href="https://www12.senado.leg.br/institucional/pessoas/pessoas">Servidor efetivo</a><a class="link link-deep" href="https://www12.senado.leg.br/institucional/pessoas/pessoas">Servidor comissionado</a><a class="link link-deep" href="https://www12.senado.leg.br/institucional/pessoas/pessoas">Servidor aposentado</a><a class="link link-deep" href="https://www12.senado.leg.br/institucional/pessoas/pessoas">Pensionista</a></div>
# <div class="my-2"><a class="link link-deep" href="https://www12.senado.leg.br/institucional/falecomosenado" title="fale com o Senado"><i class="fas fa-phone u-flip-x mr-1"></i>  Fale com o Senado</a></div>
# </div>
# <div class="divider my-2"></div>
# <div class="d-flex justify-content-xl-center"><span class="my-2">Senado Federal - Praça dos Três Poderes - Brasília DF - CEP 70165-900 |  <span class="text-nowrap">Telefone: 0800 0 61 2211</span></span></div>
# </div>
# </footer>
# </div>
# <script src="/transparencia/lib/jquery/jquery-1.12.4.min-4f252523d4af0b478c810c2547a63e19.js" type="text/javascript"></script>
# <script src="/transparencia/lib/bootstrap-2.3.2/js/bootstrap.min-bed31fb959612a0a77d8e87b9d0b3683.js" type="text/javascript"></script>
# <script src="/transparencia/lib/bootstrap-datepicker/bootstrap-datepicker-c4d744b227a1abd042c92f04a2a310e1.js" type="text/javascript"></script>
# <script src="/transparencia/lib/bootstrap-datepicker/locales/bootstrap-datepicker.pt-BR-2b702f10c90440a1bd15133ae9768bd0.js" type="text/javascript"></script>
# <script src="/transparencia/lib/essencial-2020/js/essencial-0528b73cc844243c240e73b71c2427aa.js" type="text/javascript"></script>
# <script src="/transparencia/lib/jstree/jstree.min-533a703cea4af4a8420a6d1dac814701.js" type="text/javascript"></script>
# <script src="/transparencia/js/tooltip-05f7c672357109ce997e219ca757eada.js" type="text/javascript"></script>
# <script src="/transparencia/js/arvore-orgao-f6b4694f232c53b617f5b7ffe8ca5e63.js" type="text/javascript"></script>
# <div style="display: none;">versão: portal-transparencia - 1.8.14</div>
# </body>
# </html>

# %% [markdown]
# Visualmente não houve alteração. Contudo, o trabalho de BeautifulSoup foi interno: compreender a estrutura do HTML que foi apresentada; criar a árvore de elementos. Agora conseguimos encontrar tags, classes etc. Isso pode ser feito com:
#
# - `find()` ([documentação](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find)), para elemento único ou o primeiro elemento; ou
#
# - `find_all()` ([documentação](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-all)), para elemento que aparece mais de uma vez e seus descendentes.
#
# (Há outras formas de encontrar elementos pela posição, como `find_parent()` e `find_next_sibling()`. Elas estão descritas na [documentação](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-the-tree).)
#
# Como argumentos, podemos usar a tag HTML e,opcionalmente, classe ou id de CSS.
#
# Vamos ver como encontramos `<table>` (tabela). Primeiro, somente com `find("table")`, onde obtemos o primeiro valor disponível...

# %%
print(content.find("table"))
# Out:
# <table class="table table-striped">
# <caption class="sr-only">Valores de Cotas para Exercício da Atividade Parlamentar</caption>
# <thead>
# <tr>
# <th>Recurso</th>
# <th class="valor">Valor</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td title="Aluguel de imóveis para escritório político, compreendendo despesas concernentes a eles."><i class="icon-angle-right"></i>
# 													Aluguel de imóveis para escritório político
#
# 												</td>
# <td class="valor">
# <a href="ceaps/1/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Aluguel de imóveis para escritório político"><span>23.417,86</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Aquisição de material de consumo para uso no escritório político, inclusive aquisição ou locação de software, despesas postais, aquisição de publicações, locação de móveis e de equipamentos."><i class="icon-angle-right"></i>
# 													Aquisição de material de consumo
#
# 												</td>
# <td class="valor">
# <a href="ceaps/2/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Aquisição de material de consumo"><span>35,10</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Locomoção, hospedagem, alimentação, combustíveis e lubrificantes"><i class="icon-angle-right"></i>
# 													Locomoção, hospedagem, alimentação e combustíveis
#
# 												</td>
# <td class="valor">
# <a href="ceaps/3/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Locomoção, hospedagem, alimentação e combustíveis"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar"><i class="icon-angle-right"></i>
# 													Contratação de serviços de apoio ao parlamentar
#
# 												</td>
# <td class="valor">
# <a href="ceaps/4/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Contratação de serviços de apoio ao parlamentar"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Divulgação da atividade parlamentar"><i class="icon-angle-right"></i>
# 													Divulgação da atividade parlamentar
#
# 												</td>
# <td class="valor">
# <a href="ceaps/5/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Divulgação da atividade parlamentar"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Passagens aéreas, aquáticas e terrestres nacionais"><i class="icon-angle-right"></i>
# 													Passagens aéreas, aquáticas e terrestres nacionais
#
# 												</td>
# <td class="valor">
# <a href="ceaps/8/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Passagens aéreas, aquáticas e terrestres nacionais"><span>12.708,44</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Serviços de Segurança Privada"><i class="icon-angle-right"></i>
# 													Serviços de Segurança Privada
#
# 												</td>
# <td class="valor">
# <a href="ceaps/9/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Serviços de Segurança Privada"><span>0,00</span>
# </a>
# </td>
# </tr>
# </tbody>
# <tfoot>
# <tr>
# <td>Total</td>
# <td class="valor">36.161,40</td>
# </tr>
# </tfoot>
# </table>

# %% [markdown]
# ...depois, com `find_all("table")`, em que obtemos uma lista com todos os elementos `<table>` na página.

# %%
print(content.find_all("table"))
# Out:
# [<table class="table table-striped">
# <caption class="sr-only">Valores de Cotas para Exercício da Atividade Parlamentar</caption>
# <thead>
# <tr>
# <th>Recurso</th>
# <th class="valor">Valor</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td title="Aluguel de imóveis para escritório político, compreendendo despesas concernentes a eles."><i class="icon-angle-right"></i>
# 													Aluguel de imóveis para escritório político
#
# 												</td>
# <td class="valor">
# <a href="ceaps/1/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Aluguel de imóveis para escritório político"><span>23.417,86</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Aquisição de material de consumo para uso no escritório político, inclusive aquisição ou locação de software, despesas postais, aquisição de publicações, locação de móveis e de equipamentos."><i class="icon-angle-right"></i>
# 													Aquisição de material de consumo
#
# 												</td>
# <td class="valor">
# <a href="ceaps/2/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Aquisição de material de consumo"><span>35,10</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Locomoção, hospedagem, alimentação, combustíveis e lubrificantes"><i class="icon-angle-right"></i>
# 													Locomoção, hospedagem, alimentação e combustíveis
#
# 												</td>
# <td class="valor">
# <a href="ceaps/3/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Locomoção, hospedagem, alimentação e combustíveis"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar"><i class="icon-angle-right"></i>
# 													Contratação de serviços de apoio ao parlamentar
#
# 												</td>
# <td class="valor">
# <a href="ceaps/4/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Contratação de serviços de apoio ao parlamentar"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Divulgação da atividade parlamentar"><i class="icon-angle-right"></i>
# 													Divulgação da atividade parlamentar
#
# 												</td>
# <td class="valor">
# <a href="ceaps/5/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Divulgação da atividade parlamentar"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Passagens aéreas, aquáticas e terrestres nacionais"><i class="icon-angle-right"></i>
# 													Passagens aéreas, aquáticas e terrestres nacionais
#
# 												</td>
# <td class="valor">
# <a href="ceaps/8/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Passagens aéreas, aquáticas e terrestres nacionais"><span>12.708,44</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Serviços de Segurança Privada"><i class="icon-angle-right"></i>
# 													Serviços de Segurança Privada
#
# 												</td>
# <td class="valor">
# <a href="ceaps/9/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Serviços de Segurança Privada"><span>0,00</span>
# </a>
# </td>
# </tr>
# </tbody>
# <tfoot>
# <tr>
# <td>Total</td>
# <td class="valor">36.161,40</td>
# </tr>
# </tfoot>
# </table>, <table class="table table-striped">
# <caption class="sr-only">Valores de Gastos não inclusos nas Cotas para Exercício da Atividade Parlamentar</caption>
# <thead>
# <tr>
# <th>Recurso</th>
# <th class="valor">Valor</th>
# </tr>
# </thead>
# <tbody>
# <tr class="sen_tabela_linha_grupo">
# <td title="Despesas com Viagens Oficiais">Viagens Oficiais </td>
# <td class="valor"> 13.127,71</td>
# </tr>
# <tr>
# <td title="Diárias relacionadas a Viagens Oficiais"><i class="icon-angle-right"></i>
# 													Diárias
# 												<div class="fonte" style="text-align:justify;">
# <small> Obs.: As informações aqui disponibilizadas são atualizadas conforme o recebimento pelo Senado dos dados do Sistema Integrado de Administração Financeira do Governo Federal - SIAFI. Ordens bancárias de pagamento de diárias são exibidas após dois dias úteis da emissão. Ordens bancárias canceladas em dia posterior ao da emissão deixam de ser exibidas após o recebimento pelo Senado das informações de cancelamento do SIAFI. </small>
# </div>
# </td>
# <td class="valor">
# <a href="viagens/1/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Diárias"><span>13.127,71</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Ressarcimento de passagens relacionadas a Viagens Oficiais"><i class="icon-angle-right"></i>
# 													Ressarcimento de Passagens
#
# 												</td>
# <td class="valor">
# <a href="viagens/2/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Ressarcimento de Passagens"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td><i class="icon-angle-right"></i>  Passagens emitidas</td>
# <td class="valor">
# <a href="https://www25.senado.leg.br/documents/16011/113705825/5894.pdf" target="_blank"> Consulte </a>
# </td>
# </tr>
# <tr class="sen_tabela_linha_grupo">
# <td title="Consumo de Material do Gabinete">Consumo de Material </td>
# <td class="valor"> 1.781,96</td>
# </tr>
# <tr>
# <td title="Combustíveis"><i class="icon-angle-right"></i>
# 													Combustíveis
#
# 												</td>
# <td class="valor">
# <a href="consumo/1/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Combustíveis"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Outros materiais"><i class="icon-angle-right"></i>
# 													Outros materiais
#
# 												</td>
# <td class="valor">
# <a href="consumo/2/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Outros materiais"><span>1.781,96</span>
# </a>
# </td>
# </tr>
# <tr class="sen_tabela_linha_grupo">
# <td title="Cotas Postais">Correios </td>
# <td class="valor"><a href="correios/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Correios">21.157,43</a> </td>
# </tr>
# </tbody>
# <tfoot>
# <tr>
# <td>Total</td>
# <td class="valor">36.067,10</td>
# </tr>
# </tfoot>
# </table>, <table class="table table-striped">
# <caption class="sr-only">Uso de Benefícios</caption>
# <thead>
# <tr>
# <th>Benefício</th>
# <th>Utilização</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Auxílio-Moradia</td>
# <td>
#
#
# 																	Não utilizou.
#
#
# 															 </td>
# </tr>
# <tr>
# <td>Imóvel Funcional</td>
# <td>
# <a data-target="#modalBeneficios" data-toggle="modal" href="beneficios/?numeroFuncional=341232&amp;ano=2021">Utilizou (3 meses)</a>
# </td>
# </tr>
# </tbody>
# </table>, <table class="table table-striped">
# <caption class="sr-only">Quantidade de
# 													funcionários por local e vínculo</caption>
# <thead>
# <tr>
# <th>Local / Vínculo</th>
# <th class="valor">Quantidade</th>
# </tr>
# </thead>
# <tbody>
# <tr class="sen_tabela_linha_grupo">
# <td><span>Gabinete</span></td>
# <td class="valor"><a href="pessoal/?local=gabinete&amp;ano=2021&amp;vinculo=TODOS#conteudo_transparencia" title="Ver lista de funcionários no Gabinete">
# 																	19 pessoa(s)
#
# 															</a></td>
# </tr>
# <tr>
# <td><i class="icon-angle-right"></i> <span>Comissionados</span></td>
# <td class="valor"><a href="pessoal/?local=gabinete&amp;ano=2021&amp;vinculo=COMISSIONADO#conteudo_transparencia" title="Ver lista de Comissionados no Gabinete">
# 																	18 pessoa(s)
# 															</a></td>
# </tr>
# <tr>
# <td><i class="icon-angle-right"></i> <span>Efetivos</span></td>
# <td class="valor"><a href="pessoal/?local=gabinete&amp;ano=2021&amp;vinculo=EFETIVO#conteudo_transparencia" title="Ver lista de Efetivos no Gabinete">
# 																	1 pessoa(s)
# 															</a></td>
# </tr>
# <tr class="sen_tabela_linha_grupo">
# <td><span>Escritório(s) de Apoio</span></td>
# <td class="valor"><a href="pessoal/?local=escritorio&amp;ano=2021&amp;vinculo=TODOS#conteudo_transparencia" title="Ver lista de funcionários no Escritório(s) de Apoio">
# 																	4 pessoa(s)
#
# 															</a></td>
# </tr>
# <tr>
# <td><i class="icon-angle-right"></i> <span>Comissionados</span></td>
# <td class="valor"><a href="pessoal/?local=escritorio&amp;ano=2021&amp;vinculo=COMISSIONADO#conteudo_transparencia" title="Ver lista de Comissionados no Escritório(s) de Apoio">
# 																	4 pessoa(s)
# 															</a></td>
# </tr>
# </tbody>
# </table>, <table class="table table-striped">
# <caption class="sr-only">Consulta de subsídios e
# 													aposentadoria</caption>
# <thead>
# <tr>
# <th>Recurso</th>
# <th>Consulta</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Subsídios do Senador</td>
# <td><a href="https://www.senado.leg.br/transparencia/rh/servidores/detalhe.asp?fcodigo=3508803&amp;fvinculo=1" title="Ver subsídios do Senador">Consulte</a>
# </td>
# </tr>
# </tbody>
# </table>]

# %% [markdown]
# No exemplo, observamos múltiplas tabelas...

# %%
tabelas = content.find_all("table")
print(len(tabelas))
# Out:
# 5

# %% [markdown]
# ...mas apenas a primeira nos interessa. Como, em aulas anteriores, aprendemos a encontrar elementos em listas, usamos a posição do elemento na lista para selecioná-lo.

# %%
tabela = content.find_all("table")[0]

# %% [markdown]
# Vamos analisá-la:

# %%
print(tabela)
# Out:
# <table class="table table-striped">
# <caption class="sr-only">Valores de Cotas para Exercício da Atividade Parlamentar</caption>
# <thead>
# <tr>
# <th>Recurso</th>
# <th class="valor">Valor</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td title="Aluguel de imóveis para escritório político, compreendendo despesas concernentes a eles."><i class="icon-angle-right"></i>
# 													Aluguel de imóveis para escritório político
#
# 												</td>
# <td class="valor">
# <a href="ceaps/1/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Aluguel de imóveis para escritório político"><span>23.417,86</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Aquisição de material de consumo para uso no escritório político, inclusive aquisição ou locação de software, despesas postais, aquisição de publicações, locação de móveis e de equipamentos."><i class="icon-angle-right"></i>
# 													Aquisição de material de consumo
#
# 												</td>
# <td class="valor">
# <a href="ceaps/2/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Aquisição de material de consumo"><span>35,10</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Locomoção, hospedagem, alimentação, combustíveis e lubrificantes"><i class="icon-angle-right"></i>
# 													Locomoção, hospedagem, alimentação e combustíveis
#
# 												</td>
# <td class="valor">
# <a href="ceaps/3/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Locomoção, hospedagem, alimentação e combustíveis"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar"><i class="icon-angle-right"></i>
# 													Contratação de serviços de apoio ao parlamentar
#
# 												</td>
# <td class="valor">
# <a href="ceaps/4/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Contratação de serviços de apoio ao parlamentar"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Divulgação da atividade parlamentar"><i class="icon-angle-right"></i>
# 													Divulgação da atividade parlamentar
#
# 												</td>
# <td class="valor">
# <a href="ceaps/5/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Divulgação da atividade parlamentar"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Passagens aéreas, aquáticas e terrestres nacionais"><i class="icon-angle-right"></i>
# 													Passagens aéreas, aquáticas e terrestres nacionais
#
# 												</td>
# <td class="valor">
# <a href="ceaps/8/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Passagens aéreas, aquáticas e terrestres nacionais"><span>12.708,44</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Serviços de Segurança Privada"><i class="icon-angle-right"></i>
# 													Serviços de Segurança Privada
#
# 												</td>
# <td class="valor">
# <a href="ceaps/9/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Serviços de Segurança Privada"><span>0,00</span>
# </a>
# </td>
# </tr>
# </tbody>
# <tfoot>
# <tr>
# <td>Total</td>
# <td class="valor">36.161,40</td>
# </tr>
# </tfoot>
# </table>

# %% [markdown]
# Olhando atentamente, vemos:
#
# - os itens que desejamos estão dentro de `<td>`,
# - os `<td>`s estão dentro de `<tr>`,
# - os `<tr>`s estão dentro de `<tbody>`.
#
# Algo mais ou menos assim:
#
# ```html
# <table>
#     (um monte de coisa que não interessa)
#     <tbody>
#         <tr>
#             <td>descrição</td>
#             <td>valor</td>
#         </tr>
#         <tr>
#             <td>descrição</td>
#             <td>valor</td>
#         </tr>
#         <tr>
#             <td>descrição</td>
#             <td>valor</td>
#         </tr>
#     </tbody>
#     (outras tantas coisas que não interessam)
# </table>
# ```
#
# Assim, `<td>`s são _children_ de `<tr>`s que, por sua vez, são _children_ de `<tbody>` que, por sua vez, é _child_ de `<table>`.
#
# Por lógico, se eu pegar `<tbody>` dentro de `<table>`, pegarei tudo que está dentro de todos os `<tr>`.

# %%
tbody = tabela.find("tbody")
print(tbody)
# Out:
# <tbody>
# <tr>
# <td title="Aluguel de imóveis para escritório político, compreendendo despesas concernentes a eles."><i class="icon-angle-right"></i>
# 													Aluguel de imóveis para escritório político
#
# 												</td>
# <td class="valor">
# <a href="ceaps/1/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Aluguel de imóveis para escritório político"><span>23.417,86</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Aquisição de material de consumo para uso no escritório político, inclusive aquisição ou locação de software, despesas postais, aquisição de publicações, locação de móveis e de equipamentos."><i class="icon-angle-right"></i>
# 													Aquisição de material de consumo
#
# 												</td>
# <td class="valor">
# <a href="ceaps/2/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Aquisição de material de consumo"><span>35,10</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Locomoção, hospedagem, alimentação, combustíveis e lubrificantes"><i class="icon-angle-right"></i>
# 													Locomoção, hospedagem, alimentação e combustíveis
#
# 												</td>
# <td class="valor">
# <a href="ceaps/3/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Locomoção, hospedagem, alimentação e combustíveis"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar"><i class="icon-angle-right"></i>
# 													Contratação de serviços de apoio ao parlamentar
#
# 												</td>
# <td class="valor">
# <a href="ceaps/4/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Contratação de serviços de apoio ao parlamentar"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Divulgação da atividade parlamentar"><i class="icon-angle-right"></i>
# 													Divulgação da atividade parlamentar
#
# 												</td>
# <td class="valor">
# <a href="ceaps/5/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Divulgação da atividade parlamentar"><span>0,00</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Passagens aéreas, aquáticas e terrestres nacionais"><i class="icon-angle-right"></i>
# 													Passagens aéreas, aquáticas e terrestres nacionais
#
# 												</td>
# <td class="valor">
# <a href="ceaps/8/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Passagens aéreas, aquáticas e terrestres nacionais"><span>12.708,44</span>
# </a>
# </td>
# </tr>
# <tr>
# <td title="Serviços de Segurança Privada"><i class="icon-angle-right"></i>
# 													Serviços de Segurança Privada
#
# 												</td>
# <td class="valor">
# <a href="ceaps/9/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Serviços de Segurança Privada"><span>0,00</span>
# </a>
# </td>
# </tr>
# </tbody>

# %% [markdown]
# Agora que temos `tbody`, observamos que cada valor está dentro de um `<td>`, e cada dois `<td>`s está dentro de `<tr>`.
#
# Devemos, portanto, pegar todas (`find_all()`) as tags `tr`.
#
# A esses itens vamos dar o nome de `itens`.

# %%
itens = tbody.find_all("tr")

print(itens)
# Out:
# [<tr>
# <td title="Aluguel de imóveis para escritório político, compreendendo despesas concernentes a eles."><i class="icon-angle-right"></i>
# 													Aluguel de imóveis para escritório político
#
# 												</td>
# <td class="valor">
# <a href="ceaps/1/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Aluguel de imóveis para escritório político"><span>23.417,86</span>
# </a>
# </td>
# </tr>, <tr>
# <td title="Aquisição de material de consumo para uso no escritório político, inclusive aquisição ou locação de software, despesas postais, aquisição de publicações, locação de móveis e de equipamentos."><i class="icon-angle-right"></i>
# 													Aquisição de material de consumo
#
# 												</td>
# <td class="valor">
# <a href="ceaps/2/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Aquisição de material de consumo"><span>35,10</span>
# </a>
# </td>
# </tr>, <tr>
# <td title="Locomoção, hospedagem, alimentação, combustíveis e lubrificantes"><i class="icon-angle-right"></i>
# 													Locomoção, hospedagem, alimentação e combustíveis
#
# 												</td>
# <td class="valor">
# <a href="ceaps/3/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Locomoção, hospedagem, alimentação e combustíveis"><span>0,00</span>
# </a>
# </td>
# </tr>, <tr>
# <td title="Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar"><i class="icon-angle-right"></i>
# 													Contratação de serviços de apoio ao parlamentar
#
# 												</td>
# <td class="valor">
# <a href="ceaps/4/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Contratação de serviços de apoio ao parlamentar"><span>0,00</span>
# </a>
# </td>
# </tr>, <tr>
# <td title="Divulgação da atividade parlamentar"><i class="icon-angle-right"></i>
# 													Divulgação da atividade parlamentar
#
# 												</td>
# <td class="valor">
# <a href="ceaps/5/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Divulgação da atividade parlamentar"><span>0,00</span>
# </a>
# </td>
# </tr>, <tr>
# <td title="Passagens aéreas, aquáticas e terrestres nacionais"><i class="icon-angle-right"></i>
# 													Passagens aéreas, aquáticas e terrestres nacionais
#
# 												</td>
# <td class="valor">
# <a href="ceaps/8/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Passagens aéreas, aquáticas e terrestres nacionais"><span>12.708,44</span>
# </a>
# </td>
# </tr>, <tr>
# <td title="Serviços de Segurança Privada"><i class="icon-angle-right"></i>
# 													Serviços de Segurança Privada
#
# 												</td>
# <td class="valor">
# <a href="ceaps/9/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Serviços de Segurança Privada"><span>0,00</span>
# </a>
# </td>
# </tr>]

# %% [markdown]
# Como o que temos em `itens` é uma lista de `<td>`, podemos iterar sobre os elementos pegando os textos que estão contidos nas tags, e salvar isso tudo num dicionário.

# %%
for i in itens:
    dicionario = dict()
    dicionario["categoria"] = i.find_all('td')[0]
    dicionario["valor"] = i.find_all('td')[1]
    
    print(dicionario)
# Out:
# {'categoria': <td title="Aluguel de imóveis para escritório político, compreendendo despesas concernentes a eles."><i class="icon-angle-right"></i>
# 													Aluguel de imóveis para escritório político
#
# 												</td>, 'valor': <td class="valor">
# <a href="ceaps/1/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Aluguel de imóveis para escritório político"><span>23.417,86</span>
# </a>
# </td>}
# {'categoria': <td title="Aquisição de material de consumo para uso no escritório político, inclusive aquisição ou locação de software, despesas postais, aquisição de publicações, locação de móveis e de equipamentos."><i class="icon-angle-right"></i>
# 													Aquisição de material de consumo
#
# 												</td>, 'valor': <td class="valor">
# <a href="ceaps/2/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Aquisição de material de consumo"><span>35,10</span>
# </a>
# </td>}
# {'categoria': <td title="Locomoção, hospedagem, alimentação, combustíveis e lubrificantes"><i class="icon-angle-right"></i>
# 													Locomoção, hospedagem, alimentação e combustíveis
#
# 												</td>, 'valor': <td class="valor">
# <a href="ceaps/3/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Locomoção, hospedagem, alimentação e combustíveis"><span>0,00</span>
# </a>
# </td>}
# {'categoria': <td title="Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar"><i class="icon-angle-right"></i>
# 													Contratação de serviços de apoio ao parlamentar
#
# 												</td>, 'valor': <td class="valor">
# <a href="ceaps/4/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Contratação de serviços de apoio ao parlamentar"><span>0,00</span>
# </a>
# </td>}
# {'categoria': <td title="Divulgação da atividade parlamentar"><i class="icon-angle-right"></i>
# 													Divulgação da atividade parlamentar
#
# 												</td>, 'valor': <td class="valor">
# <a href="ceaps/5/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Divulgação da atividade parlamentar"><span>0,00</span>
# </a>
# </td>}
# {'categoria': <td title="Passagens aéreas, aquáticas e terrestres nacionais"><i class="icon-angle-right"></i>
# 													Passagens aéreas, aquáticas e terrestres nacionais
#
# 												</td>, 'valor': <td class="valor">
# <a href="ceaps/8/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Passagens aéreas, aquáticas e terrestres nacionais"><span>12.708,44</span>
# </a>
# </td>}
# {'categoria': <td title="Serviços de Segurança Privada"><i class="icon-angle-right"></i>
# 													Serviços de Segurança Privada
#
# 												</td>, 'valor': <td class="valor">
# <a href="ceaps/9/?ano=2021#conteudo_transparencia" title="Ver detalhe mês a mês de Serviços de Segurança Privada"><span>0,00</span>
# </a>
# </td>}

# %% [markdown]
# Notem que ainda temos código HTML nos resultados. Para eliminar isso, podemos passar, depois de `find_all()`, a função `text`. Também podemos usar outras funções, como `replace()`, `strip()` e `float()`. Assim:

# %%
for i in itens:
    dicionario = dict()
    dicionario["categoria"] = i.find_all('td')[0].text.strip()
    dicionario["valor"] = float(i.find_all('td')[1].text.strip().replace(".", "").replace(",", "."))
    
    print(dicionario)
# Out:
# {'categoria': 'Aluguel de imóveis para escritório político', 'valor': 23417.86}
# {'categoria': 'Aquisição de material de consumo', 'valor': 35.1}
# {'categoria': 'Locomoção, hospedagem, alimentação e combustíveis', 'valor': 0.0}
# {'categoria': 'Contratação de serviços de apoio ao parlamentar', 'valor': 0.0}
# {'categoria': 'Divulgação da atividade parlamentar', 'valor': 0.0}
# {'categoria': 'Passagens aéreas, aquáticas e terrestres nacionais', 'valor': 12708.44}
# {'categoria': 'Serviços de Segurança Privada', 'valor': 0.0}

# %% [markdown]
# Pronto. Perfeito. Raspamos os dados do senador. Podemos agora salvar colocar o dicionário numa lista e salvar como `csv` com a ajuda de Pandas.

# %%
import pandas as pd

dados = list()
for i in itens:
    dicionario = dict()
    dicionario["categoria"] = i.find_all('td')[0].text.strip()
    dicionario["valor"] = float(i.find_all('td')[1].text.strip().replace(".", "").replace(",", "."))
    dados.append(dicionario)

df = pd.DataFrame.from_dict(dados)

# %%
df
# Out:
#                                            categoria     valor
# 0        Aluguel de imóveis para escritório político  23417.86
# 1                   Aquisição de material de consumo     35.10
# 2  Locomoção, hospedagem, alimentação e combustíveis      0.00
# 3    Contratação de serviços de apoio ao parlamentar      0.00
# 4                Divulgação da atividade parlamentar      0.00
# 5  Passagens aéreas, aquáticas e terrestres nacio...  12708.44
# 6                      Serviços de Segurança Privada      0.00

# %%
df.to_csv('teste.csv', index=False)

# %% [markdown]
# Cabe ressaltar que obtivemos sete linhas, dados referentes a apenas um ano. Podemos fazer `for loop` e pegar 2 milhões de linhas de todos os anos: o código seria praticamente o mesmo.
